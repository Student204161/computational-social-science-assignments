# %% [markdown]
# # Mathias Dyhr - Computational Social Science Notes

# %% [markdown]
# ## Week 1(Web Scrabing)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.
# * Finde ud af hvor mange serial morder der er på twitter?
# * Assesing response time of companies?
# * What is peoples political views?
#
# 2.
# * Twitter, Facebook
# * Their emails, Meeting hours and company data
# * Twitter, SocMed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.
# * Wikipedia, LinkedIn,Seshatdatabank
# 2.
# * Social Complexity Dataset, twitter dataset
# 3.
# * Webscraping, and download/request data from websites
# 4.
# * Missing data, and deficiencies in data measurements, public data only

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from bs4 import BeautifulSoup ##A package to work with HTML data
import requests #A package to make HTTP requests

# %%
# 2019 part 1
LINK = "https://2019.ic2s2.org/oral-presentations/"
r = requests.get(LINK)
soup = BeautifulSoup(r.content)
div = soup.find("div",{"class":"col-md-8 page-content-wrap"})
div_p = div.find_all("p")[3:]
# div_p
for d in div_p:
    d.strong.extract()
data = []
for d in div_p:
    output = d.get_text(strip=True,separator="\n").splitlines()[1:]
    for out in output:
        if out[0].isdigit():
            removed_date = list(filter(None, out.split("–")[2:]))[0]
            removed_topic = removed_date.split(".")[0]
            researchers = removed_topic.split(",")
            for r in researchers:
                data.append(r)
        elif out.split(": ")[0] == "Chair":
            data.append(out.split(": ")[1])

data_unique = list(set(data))
len(data_unique)
# Out:
# 549

# %%
# 2019 part 2
LINK = "https://2019.ic2s2.org/posters/"
r = requests.get(LINK) 
soup = BeautifulSoup(r.content)
div = soup.find("div",{"class":"col-md-8 page-content-wrap"})
data=[]
for child in div.find("ul").children:
    txt = child.get_text(strip=True,separator="\n").split("<span>")[0].split("\n")[0]
    txt = txt.replace(" and ",", ")
    txt_split = txt.split(", ")
    for t in txt_split:
        data.append(t)
        count += 1    
count
# Out:
# 1414

# %%
# 2021 
LINK = "https://easychair.org/smart-program/IC2S2-2021/talk_author_index.html"
r = requests.get(LINK) 
soup = BeautifulSoup(r.content)
table = soup.find("table",{"class":"index"})    
 # How many people there is in total
table_rows = table.find_all("tr")
rows = []
count = 0
for tr in table_rows[1:]:
    people = tr.find_all("td","name")
    for person in people:
        count += 1
        print(person.text)
print("Number of people:", count)
# Out:
# Aberer, Karl
# Adam, Silke
# Adelani, David
# Agarwal, Nitin
# Aggarwal, Minali
# Ahn, Yong-Yeol
# Aiello, Luca
# Akbaritabar, Aliakbar
# Aksoy, Ozan
# Alessandretti, Laura
# Alexander, Monica
# Aliapoulios, Maxwell
# Allen, Jennifer
# Alorić, Aleksandra
# Alvarez-Hamelin, José-Ignacio
# Amirkhanian, Yuri A.
# An, Jisun
# Anderson, Ashton
# Aneja, Harshit
# Aramaki, Eiji
# Archer, Luke
# Arechar, Antonio
# Aref, Samin
# Aridor, Guy
# Arielli, Emanuele
# Artime, Oriol
# Axelrod, David
# Azizi Fard, Narges
# Bailey, Michael
# Bajardi, Paolo
# Balietti, Stefano
# Balsamo, Duilio
# Banisch, Sven
# Barahona, Mauricio
# Barkoczi, Daniel
# Baronchelli, Andrea
# Baronchelli, Andrea
# Bastani, Hamsa
# Bastani, Osbert
# Battiston, Alice
# Bauer, Leo
# Bedathur, Srikanta
# Beeferman, Doug
# Beersma, Bianca
# Beiró, Mariano G.
# Belli, Luca
# Bernstein, Michael S.
# Berry, George
# Bhadani, Saumya
# Bhattacharya, Indrajit
# Bhole, Monica
# Bilsen, Daniel
# Blackburn, Jeremy
# Bohm, Matteo
# Boichenko, Anton
# Bokanyi, Eszter
# Borgmann, Philip
# Boros, Krisztián
# Bozarth, Lia
# Bracci, Alberto
# Brambilla, Marco
# Brand, Alexander
# Breuer, Johannes
# Brinkmann, Levin
# Brito, Kevin
# Brooke, Sian
# Brunet, Marc-Etienne
# Bryden, John
# Budak, Ceren
# Burton, Jason
# Böttcher, Lucas
# Candia, Cristian
# Cao, Hancheng
# Cao, Likun
# Carbone, Luca
# Cardon, Dominique
# Carley, Kathleen
# Carnegie, Nicole B.
# Castaldo, Nicola
# Catasta, Michele
# Cebrian, Manuel
# Cebrian, Manuel
# Celis, Elisa
# Cha, Meeyoung
# Cha, Meeyoung
# Cha, Meeyoung
# Chae, Je Hoon
# Chang, Ho-Chun Herbert
# Chang, Serina
# Chaparro, Luisa Fernanda
# Chen, Anthony
# Chen, Hong
# Chen, Huei-Yen
# Chen, Juan
# Chen, Liangwei
# Chen, Tsuhan
# Chen, Victor
# Chen, Yingying
# Chen, Yutao
# Chen, Ziwen
# Cherifi, Hocine
# Cheung, Pui Yin
# Chiolero, Arnaud
# Choi, Eunseo
# Choi, Minje
# Choudhari, Jayesh
# Ciampaglia, Giovanni Luca
# Clauset, Aaron
# Clever, Lena
# Clever, Nico
# Cointet, Jean-Philippe
# Colavizza, Giovanni
# Comes, Tina
# Constantino, Isabel
# Constantino, Isabel
# Conte Keivabu, Risto
# Cork, Alicia
# Corten, Rense
# Costas, Rodrigo
# Cottica, Alberto
# Criscione, Teodoro
# Crockett, Molly J.
# Cui, Hao
# Czerwinski, Mary
# Czymara, Christian
# D'Andrea, Valeria
# Dacon, Jamell
# Dambanemuya, Henry
# Danus, Lluis
# Das, Subhro
# Dasgupta, Anirban
# de Almeida, Igor
# De Cristofaro, Emiliano
# De Domenico, Manlio
# De Domenico, Manlio
# De Francisci Morales, Gianmarco
# De Francisci Morales, Gianmarco
# de Jong, Rachel
# Dehmamy, Nima
# Deitrick, James
# Del Fava, Emanuele
# Delnoij, Joyce
# Dementeva, Yulia
# Denecke, Esther
# Deverna, Matthew R.
# Dhillon, Paramveer
# Di Natale, Anna
# Diarrassouba, N'Godjigui Junior
# Dikaiakos, Marios
# Diviák, Tomáš
# Doi, Shohei
# Dokuka, Sofia
# Domahidi, Emese
# Du, Yuhao
# Duricic, Tomislav
# Eckles, Dean
# Elmas, Tugrulcan
# Endah Sulistiawati, Amin
# Ertekin, Şeyda
# Estrada, Camilo
# Evans, James
# Evans, James
# Fagan, Jesse Michael
# Ferrara, Emilio
# Ferreira, Leonardo
# Firmansyah, Firman
# Flaherty, Kristen
# Flammini, Alessandro
# Flammini, Alessandro
# Flöck, Fabian
# Font-Pomarol, Lluc
# Fortunato, Santo
# Foucault Welles, Brooke
# Fraiberger, Samuel
# Francisco, Frederico
# Frank, Morgan
# Frankowski, Dan
# Fregolent Mendes de Oliveira, Diego
# Frey, Seth
# Frischlich, Lena
# Froio, Caterina
# Gaffney, Devin
# Galesic, Mirta
# Gallo, Angela
# Gallo, Angela
# Gallotti, Riccardo
# Gandica, Yérali
# Gangavaram, Abiram
# Gao, Jian
# Garcia, David
# Garcia, David
# Garcia-Bernardo, Javier
# Garimella, Kiran
# Gergle, Darren
# Gersbach, Hans
# Getoor, Lise
# Gezerli, Deniz
# Ghasemian, Amir
# Ghosh, Sayan
# Gligoric, Kristina
# Goldenberg, Amit
# Goldstein, Daniel G.
# Gonçalves-Sá, Joana
# Gonçalves-Sá, Joana
# Grabowicz, Przemyslaw
# Graus, Ger
# Gray, Ian
# Grayson, Siobhan
# Greene, Derek
# Gross, James
# Grund, Thomas
# Guba, Katerina
# Guimera, Roger
# Guimerà, Roger
# Guo, Weisi
# Gurajada, Sairam
# Gómez, Francisco
# Gökay Emel, A. Gül
# Haberly, Daniel
# Hadler, Markus
# Hagens, Marloes
# Hahn, Ulrike
# Haider, Samar
# Hale, Scott
# Han, Sungwon
# Hangen, Forrest
# Hannan, Jacqueline
# Harris, Martyn
# Hartmann, Valentin
# Harutyunyan, Ani
# Hassoun, Amelia
# He, Sijun
# He, Yuanmo
# Hecht, Brent
# Helic, Denis
# Hemelrijk, Charlotte
# Hernández, Laura
# Hills, Thomas
# Ho, Justin Chun-Ting
# Hoferer, Moritz
# Hofstra, Bas
# Hong, Inho
# Hoover, Joe
# Horta Ribeiro, Manoel
# Horvitz, Eric
# Horvát, Emőke-Ágnes
# Hosseinioun, Mohamad
# Hosseinmardi, Homa
# Hosseinmardi, Homa
# Hu, Margaret
# Hu, Xinlan Emily
# Huang, Shengchun
# Hui, Pik-Mai
# Hurtado Bodell, Miriam
# Inkaya, Tulin
# Iqbal, Shamsi
# Irlenbusch, Bernd
# Itao, Kenji
# Jacobson, Jessica
# Jaidka, Kokil
# Jakobi, Ákos
# Janský, Petr
# Javadian Sabet, Alireza
# Jensen, Henrik
# Jhaver, Shagun
# Jin, Ching
# Jing, Elise
# Johnson, Isaac
# Johnson, Kara L.
# Johnson, Shane
# Jones, Benjamin
# Jones, Keenan
# Joseph, Kenneth
# Josifovska, Maya
# Juhász, Sándor
# Jung, Woo-Sung
# Jurgens, David
# Juul, Jonas L.
# Kalimeri, Kyriaki
# Kanazawa, Kiyoshi
# Kaneko, Kunihiko
# Kapuza, Anastasiia
# Karsai, Márton
# Kas, Judith
# Katona, Eszter
# Katzman, Jared
# Kaufmann, Talia
# Kazemi, Ashkan
# Kekkonen, Arto
# Kertész, János
# Keuchenius, Anna
# Keuschnigg, Marc
# Khudabukhsh, Ashiqur
# Kiciman, Emre
# Kim, Lanu
# Kim, Sundong
# Kishore Shahi, Gautam
# Kizilcec, Rene
# Kleinberg, Bennett
# Kleinberg, Jon
# Klimek, Peter
# Klimmt, Christoph
# Klösch, Beate
# Kmetty, Zoltán
# Kobayashi, Ryota
# Kohne, Julian
# Kojaku, Sadamori
# Kojaku, Sadamori
# Koltai, Júlia
# Koschate, Miriam
# Kotzinos, Dimitris
# Kovács, Ádám
# Kreuter, Frauke
# Kteily, Nour
# Kubik, Jan
# Kumar, Shankar
# Kurizaki, Shuhei
# Kusumegi, Keigo
# Köbis, Nils
# König, Tim
# LaBerge, Nicholas
# Labiancaba, Giuseppe Joe
# Lackner, Simone
# Larremore, Daniel B.
# Lasser, Jana
# Lastra-Anadon, Carlos X.
# Laurer, Moritz
# Leclercq, Eric
# Lee, Chia-Jung
# Lee, Eun
# Lee, Hansol
# Lee, Jonghyun
# Lee, Kangsan
# Lee, Sang Yup
# Lee, Seungeon
# Lee, Yu Jin
# Lehmann, Sune
# Lelkes, Yphtach
# Lemmerich, Florian
# Lengyel, Balazs
# Lengyel, Balázs
# Lepri, Bruno
# Leskovec, Jure
# Levene, Mark
# Lex, Elisabeth
# Li, Bryan
# Li, Muyang
# Li, Shujun
# Li, Weifeng
# Li, Xiancheng
# Liew, Kongmeng
# Lin, Yiling
# Linares, Julio
# Liu, David
# Liu, Feifan
# Liu, Haochen
# Liu, Tanzhou
# Lofdahl, Corey
# Lofdahl, Lara
# Lohmann, Sophie
# Lomax, Nik
# Lu, Yingdan
# Lucchini, Lorenzo
# Lukac, Martin
# Luo, Lan
# Luo, Zhifan
# Lupton, Deborah
# Lyu, Zeyu
# Ma, Gloria Wai Shan
# Macy, Michael
# Madani, Navid
# Magnusson, Måns
# Maheshwari, Kartiki
# Mai, Tung-Duong
# Maity, Suman Kalyan
# Majchrzak, Tim A
# Makhortykh, Mykola
# Mancoridis, Marina
# Mannem, Karunakar Reddy
# Manovich, Lev
# Margarita, Leib
# Martel, Cameron
# Mathew, Binny
# Mattsson, Carolina
# May, Tiggey
# McClure, David
# McCoy, Damon
# McGuinness, Harvey
# McIlroy-Young, Reid
# Medvec, Victoria
# Medya, Sourav
# Mejova, Yelena
# Melançon, Guy
# Menczer, Filippo
# Mendelsohn, Julia
# Mengzhen, Jia
# Menshikova, Anastasia
# Mepham, Kieran
# Mesquita, Sara
# Mesquita, Sara
# Messing, Solomon
# Metzler, Hannah
# Mijs, Jonathan
# Milbauer, Jeremiah
# Milojević, Staša
# Min, Seokyoung
# Mishra, Shubhanshu
# Mishra, Sudhanshu
# Mitchell, Lewis
# Mitrović Dankulov, Marija
# Miyazaki, Kunihiro
# Mizuno, Takayuki
# Mobius, Markus
# Mogoutov, Andreï
# Mole, Richard
# Molnár, Anna
# Monti, Corrado
# Morgan, Allison
# Moro, Esteban
# Mosleh, Mohsen
# Mukerjee, Subhayan
# Mukherjee, Animesh
# Mukherjee, Deblina
# Mukhina, Ksenia
# Munoz-Najar Galvez, Sebastian
# Muntaner, Carles
# Murayama, Taichi
# Muric, Goran
# Murray, Dakota
# Müller, Thomas F.
# Nadini, Matthieu
# Nanni, Mirco
# Napoli, Ludovico
# Narvaez, Luz Angela
# Nasarre-Aznar, Sergio
# Naserian, Elahe
# Nasim, Mehwish
# Neal, Zachary
# Neffke, Frank
# Neuhäuser, Leonie
# Neumann, Frank
# Nicolaides, Christos
# Nicolaou, Nicos
# Niederkrotenthaler, Thomas
# Nordell, Jessica
# Novák, Martin
# Nurse, Jason
# Nussberger, Anne-Marie
# Nyhan, Brendan
# O'Brien, Daniel
# O'Toole, Katherine
# Ofli, Ferda
# Okan, Oral
# Ooghe-Tabanou, Benjamin
# Overdorf, Rebekah
# Ozyurt, Yilmazcan
# Palanský, Miroslav
# Pallis, George
# Pan, Jennifer
# Panisson, André
# Panzarasa, Pietro
# Pappalardo, Luca
# Parigi, Paolo
# Park, Jaehyuk
# Park, Jaehyuk
# Park, Sungkyu
# Parkinson, Brian
# Pathak, Arjunil
# Pei, Jiaxin
# Pellert, Max
# Peng, Hao
# Peng, Hongwei
# Pennycook, Gordon
# Pentland, Alex
# Perello, Nicholas
# Perfeito, Lília
# Perotti, Alan
# Perrier, Rémi
# Perry, Brea
# Pescetelli, Niccolo
# Pescetelli, Niccolò
# Petricli, Gulcan
# Peyrard, Maxime
# Piarso, Chrysan Angela
# Piccardi, Tiziano
# Pierri, Francesco
# Pilgrim, Charlie
# Pinaud, Bruno
# Plique, Guillaume
# Podder, Shirsendu
# Possler, Daniel
# Pozzana, Iacopo
# Prasad, Shivangi
# Pratama, Ahmad
# Preniqi, Vjosa
# Prifti, Ylli
# Provetti, Alessandro
# Pulido, Cristian
# Pulido, Maria Teresa
# Qian, Yifan
# Quercia, Daniele
# Raghavan, Hari
# Rahwan, Iyad
# Rajadesingan, Ashwin
# Rajeh, Stephany
# Rama, Daniele
# Ramaciotti Morales, Pedro
# Rand, David
# Raymond, Cameron
# Redi, Miriam
# Reiss, Michael
# Reiter-Haas, Markus
# Renoust, Benjamin
# Resnick, Paul
# Revina, Polina
# Rezaei, Sarah
# Richardson, Allissa
# Richter, Lukas
# Righi, Simone
# Rilke, Rainer
# Rimé, Bernard
# Rintel, Sean
# Rio, Pedro
# Romero, Daniel
# Rothschild, David
# Roy, Brandon
# Roy, Deb
# Rudas, Jorge
# Ruprechter, Thorsten
# Rutherford, Alex
# S Chan, Kevin
# Sacco, Pierluigi
# Sacco, Pierluigi
# Sachin, P Kumar
# Sadeghi, Mohammad Amin
# Saez-Trumper, Diego
# Sage, Melanie
# Saha, Punyajoy
# Sahasranaman, Anand
# Saitis, Charalampos
# Sales-Pardo, Marta
# Sales-Pardo, Marta
# Salomone, Alberto
# Samory, Mattia
# Sandvig, Christian
# Sanford, Mary
# Sano, Yukie
# Sanyoura, Lana
# Sarva, Sahiti
# Sasahara, Kazutoshi
# Saveski, Martin
# Savonnet, Marinette
# Schatto-Eckrodt, Tim
# Schaub, Michael
# Schawe, Hendrik
# Schecter, Aaron
# Scheper, Jule
# Schifanella, Rossano
# Schifanella, Rossano
# Schindler, Max
# Schmid, Daniela
# Schulze, Heidi
# Schöne, Jonas Paul
# Schünemann, Wolf
# Secchini, Valeria
# Seiser, Volker
# Sen, Indira
# Sen, Siddhartha
# Sert, Egemen
# Shamon, Hawal
# Shan, Wei
# Shirado, Hirokazu
# Sinchaisri, Park
# Singh, Karandeep
# Sirenko, Mikhail
# Sirianni, Antonio
# Sivak, Elizaveta
# Skorupski, Ryan
# Smirnov, Ivan
# Soares, Cláudia
# Sokolov, Mikhail
# Soldner, Felix
# Song, Hyunho
# Sorger, Johannes
# Sornette, Didier
# Spitz, Andreas
# Stamm, Felix
# State, Bogdan
# Stecklov, Guy
# Stefanelli, Alberto
# Stefanidis, Dimosthenis
# Stein, Jonas
# Stier, Sebastian
# Stine, Zachary
# Stone, Lydia
# Stringhini, Gianluca
# Strohmaier, Markus
# Sverdlov, Michael
# Szell, Micheal
# Takacs, Karoly
# Takes, Frank
# Takikawa, Hiroki
# Takikawa, Hiroki
# Tama, Bayu Adhi
# Tan, Ying Kiat
# Tang, Jiliang
# Teevan, Jaime
# Teixeira Santos, Tiago
# Telling, Anna
# Temps, Johanna
# Terse, Omkar
# Testori, Martina
# Teytelboym, Alexander
# Thurner, Stefan
# Tittel, Katharina
# Tomašević, Aleksandar
# Tonneau, Manuel
# Torres-Lugo, Christopher
# Toth, Roland
# Toyoda, Masashi
# Tsivinskaya, Angelika
# Tsurushima, Akira
# Tsvetkova, Milena
# Turner, Benjamin
# Törnberg, Petter
# Uchida, Yukiko
# Ugander, Johan
# Uitermark, Justus
# Urman, Aleksandra
# Uzzi, Brian
# Valle, Francesco
# Van Buskirk, Ian
# van de Rijt, Arnout
# van der Loo, Mark
# van Tubergen, Frank
# Varela-Lasheras, Irma
# Varga, Krisztian
# Varshney, Kush R.
# Vashevko, Anthony
# Vaucher, Timoté
# Verbraeck, Alexander
# Vergara, Jan Voltaire
# Veselovsky, Veniamin
# Victorino, Jorge
# Vieira, Carolina
# Villa-Cox, Ramon
# Vitalis, Kyriacos
# von Horn, Roland
# von Kleist, Kira
# Vranić, Ana
# Wagner, Claudia
# Wakamiya, Shoko
# Waller, Isaac
# Walsh, Jennifer L.
# Wang, Dashun
# Wang, Leping
# Wang, Luping
# Wang, Russell
# Wang, Xinyi
# Wang, Yang
# Wapman, K. Hunter
# Wapman, K. Hunter
# Watts, Duncan
# Watts, Duncan
# Weber, Derek
# Weber, Ingmar
# Weiß, Bernd
# Weller, Katrin
# West, Robert
# White, Ryen W
# Whiting, Mark E.
# Wijayanto, Arie
# Willer, Robb
# Wong, Priscilla
# Wu, Lingfei
# Wulf, Tim
# Xia, Haoxiang
# Xiaolei, Guo
# Xinyue, Wang
# Xu, Wentao
# Yalov, Timofey
# Yamaya, Shun
# Yan, Jason
# Yang, Kai-Cheng
# Yang, Longqi
# Yang, Vicky Chuqiao
# Yang, Vivian
# Yang, Yunkang
# Yap, Jin
# Yin, Yian
# Yoon, Jisung
# Yoon, Jisung
# Youn, Hyejin
# Yu, Renzhe
# Yu, Yulin
# Yundi, Zhang
# Zagheni, Emilio
# Zagheni, Emilio
# Zannettou, Savvas
# Zemel, Richard
# Zeng, Helen
# Zhang, Sam
# Zhang, Shuang
# Zhang, Wei
# Zhao, Chuqing
# Zhao, Xinyi
# Zheng, Sylvan
# Zhong, Qiankun
# Zhou, Alvin
# Zhuchkova, Svetlana
# Zhunis, Assem
# Zia, Leila
# Ziegler, John
# Özbilen, Alper
# Özdemir, Suat
# Özkalay, Ahmed Furkan
# Number of people: 716

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 2021 
LINK = "https://easychair.org/smart-program/IC2S2-2021/talk_author_index.html"
r = requests.get(LINK) 
soup = BeautifulSoup(r.content)
table = soup.find("table",{"class":"index"})    
 # How many people there is in total
#How many unique people in total
table_rows = table.find_all("tr")
rows = []
people_set = set()
for tr in table_rows[1:]:
    people = tr.find_all("td","name")
    for person in people:
        people_set.add(person.text)
#print("Number of unique people:", len(people_set))
print(people_set)
# Out:
# {'Muntaner, Carles', 'Lasser, Jana', 'Peng, Hao', 'Luo, Lan', 'Parigi, Paolo', 'Katona, Eszter', 'Pappalardo, Luca', 'Hassoun, Amelia', 'Brunet, Marc-Etienne', 'Lackner, Simone', 'Kmetty, Zoltán', 'Janský, Petr', 'Lehmann, Sune', 'Schulze, Heidi', 'Pescetelli, Niccolò', 'Jurgens, David', 'Yu, Renzhe', 'Youn, Hyejin', 'Adelani, David', 'Perello, Nicholas', 'Madani, Navid', 'McGuinness, Harvey', 'Deitrick, James', 'Shirado, Hirokazu', 'Rilke, Rainer', 'Horvitz, Eric', 'Laurer, Moritz', 'Bohm, Matteo', 'Mepham, Kieran', 'Ciampaglia, Giovanni Luca', 'Dokuka, Sofia', 'Pallis, George', 'Rama, Daniele', 'Zhao, Xinyi', 'Zheng, Sylvan', 'Tittel, Katharina', 'Dementeva, Yulia', 'Manovich, Lev', 'Turner, Benjamin', 'Kteily, Nour', 'Liu, David', 'Stefanelli, Alberto', 'Savonnet, Marinette', 'Haberly, Daniel', 'Li, Xiancheng', 'Sert, Egemen', 'Comes, Tina', 'Di Natale, Anna', 'Choudhari, Jayesh', 'Lu, Yingdan', 'Catasta, Michele', 'Wapman, K. Hunter', 'Hui, Pik-Mai', 'Kalimeri, Kyriaki', 'Elmas, Tugrulcan', 'Testori, Martina', 'Levene, Mark', 'Victorino, Jorge', 'Wakamiya, Shoko', 'Kim, Sundong', 'Khudabukhsh, Ashiqur', 'Horvát, Emőke-Ágnes', 'Sadeghi, Mohammad Amin', 'Arielli, Emanuele', 'Xia, Haoxiang', 'Colavizza, Giovanni', 'Tsurushima, Akira', 'Harris, Martyn', 'Karsai, Márton', 'Das, Subhro', 'Willer, Robb', 'Kaneko, Kunihiko', 'Kim, Lanu', 'Gallo, Angela', 'Cao, Hancheng', 'Martel, Cameron', 'Pratama, Ahmad', 'Telling, Anna', 'Tomašević, Aleksandar', 'Grayson, Siobhan', 'Hu, Xinlan Emily', 'He, Yuanmo', 'Zia, Leila', 'Grabowicz, Przemyslaw', 'An, Jisun', 'Nordell, Jessica', 'Neuhäuser, Leonie', 'Kovács, Ádám', 'Brambilla, Marco', 'Cao, Likun', 'Pozzana, Iacopo', 'Clever, Lena', 'Pentland, Alex', 'Sverdlov, Michael', 'Allen, Jennifer', 'Ferrara, Emilio', 'Lee, Yu Jin', 'Jacobson, Jessica', 'Gray, Ian', 'Li, Muyang', 'Bhattacharya, Indrajit', 'Chen, Ziwen', 'Goldstein, Daniel G.', 'Secchini, Valeria', 'Brand, Alexander', 'Pilgrim, Charlie', 'von Kleist, Kira', 'Axelrod, David', 'Chen, Liangwei', 'Lepri, Bruno', 'Yap, Jin', 'Stier, Sebastian', 'Pierri, Francesco', 'Horta Ribeiro, Manoel', 'Balietti, Stefano', 'Hills, Thomas', 'Amirkhanian, Yuri A.', 'Artime, Oriol', 'Pennycook, Gordon', 'Yalov, Timofey', 'Yang, Yunkang', 'Beiró, Mariano G.', 'Chaparro, Luisa Fernanda', 'Wang, Leping', 'Hagens, Marloes', 'Sirianni, Antonio', 'Toyoda, Masashi', 'Nasarre-Aznar, Sergio', 'Corten, Rense', 'Kiciman, Emre', "O'Toole, Katherine", 'Piarso, Chrysan Angela', 'Takacs, Karoly', 'Gómez, Francisco', 'Gandica, Yérali', 'Agarwal, Nitin', 'Sacco, Pierluigi', 'Helic, Denis', 'Celis, Elisa', 'Bastani, Hamsa', 'Hofstra, Bas', 'Harutyunyan, Ani', 'Reiss, Michael', 'Ooghe-Tabanou, Benjamin', 'Burton, Jason', 'Menczer, Filippo', 'Chae, Je Hoon', 'Medya, Sourav', 'Sahasranaman, Anand', 'Czerwinski, Mary', 'Frank, Morgan', 'Hale, Scott', 'Yan, Jason', 'Jaidka, Kokil', 'Messing, Solomon', 'Sornette, Didier', 'Juhász, Sándor', 'Garcia-Bernardo, Javier', 'Garimella, Kiran', 'Vashevko, Anthony', 'Veselovsky, Veniamin', 'Wang, Xinyi', 'Wulf, Tim', 'Chen, Yutao', 'Zhao, Chuqing', 'Monti, Corrado', 'Lee, Seungeon', 'Rajeh, Stephany', 'Raymond, Cameron', 'Hurtado Bodell, Miriam', 'Costas, Rodrigo', 'Mukhina, Ksenia', 'Fraiberger, Samuel', 'Bauer, Leo', 'Quercia, Daniele', 'Wang, Russell', 'Pathak, Arjunil', 'Hong, Inho', 'Han, Sungwon', 'May, Tiggey', 'von Horn, Roland', 'Rio, Pedro', 'Mejova, Yelena', 'Garcia, David', 'Jhaver, Shagun', 'Fagan, Jesse Michael', 'Varga, Krisztian', 'Cebrian, Manuel', 'Kas, Judith', 'Qian, Yifan', 'Perrier, Rémi', 'Smirnov, Ivan', 'Gross, James', 'Mengzhen, Jia', 'Richardson, Allissa', 'Özbilen, Alper', "D'Andrea, Valeria", 'Berry, George', 'Schünemann, Wolf', 'Sachin, P Kumar', 'Sanyoura, Lana', 'Morgan, Allison', 'S Chan, Kevin', 'Bastani, Osbert', 'Samory, Mattia', 'Mitrović Dankulov, Marija', 'Shan, Wei', 'Wijayanto, Arie', 'Galesic, Mirta', 'Takes, Frank', 'Tama, Bayu Adhi', 'Ruprechter, Thorsten', 'Rutherford, Alex', 'Uzzi, Brian',  ...

# %% [markdown]
# ## Week 2(API)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Graph API
#  - The Graph API is the primary way for apps to read and write to the Facebook social graph.
#  - The rate limits for the Facebook Graph API depend on the type of access token being used and the API version. As of my training data (2021), some of the rate limits for the Graph API are:
#
#  - User access tokens:
#   - 60 requests per user per minute, up to a maximum of 200 requests per app per minute.
#  - App access tokens:
#   - 600 requests per minute for apps, up to a maximum of 200 requests per app per minute.
#  - Page access tokens:
#   - 200 requests per user per minute, up to a maximum of 200 requests per app per minute.
#
# 2. Google Maps API
#  - For mapping and location data.
#  - While there is no maximum number of requests per day, the following usage limits are in place for the Maps JavaScript  API:
#  -  30,000 requests per minute.
#  -  300 requests per minute per IP address. In the Google Cloud Console, this quota is referred to as Map loads per minute    per user.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests

# %%
import numpy as np
names = list(np.load("names.npy"))

# %%
BASE_URL = "https://api.semanticscholar.org/graph/"
VERSION = "v1/"
AUTHOR = "author/search"

# %%
author_ids = []
for name in names:  
    params = {'query':name,
                "fields":"name,papers.title,papers.authors"}

# %%
my_url = BASE_URL + VERSION + AUTHOR

# %%
r = requests.get(my_url, params=params)
r_json = r.json()
if r_json["total"] != 0:
    r_data = r_json["data"][0]
    author_ids.append(r_data["authorId"])
    
    for paper in r_data["papers"]:
        for author in paper["authors"]:
            author_ids.append(author["authorId"])
r_json
# Out:
# {'total': 7,
#  'offset': 0,
#  'data': [{'authorId': '2087659410',
#    'name': 'T. Müller',
#    'papers': [{'paperId': '85833f2628545d7b08a6db4e9029ad2020c7a1d0',
#      'title': 'Cultural Evolution of Precise and Agreed-Upon Semantic Conventions in a Multiplayer Gaming App',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '144929327', 'name': 'James Winters'}]},
#     {'paperId': '1b3887eb52795180e3a02c4f6fdfaab2f9bafb4a',
#      'title': 'Hybrid social learning in human-algorithm cultural transmission',
#      'authors': [{'authorId': '1678486592', 'name': 'L. Brinkmann'},
#       {'authorId': '2174486558', 'name': 'D. Gezerli'},
#       {'authorId': '118644540', 'name': 'K. V. Kleist'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '1705156', 'name': 'I. Rahwan'},
#       {'authorId': '6050548', 'name': 'N. Pescetelli'}]},
#     {'paperId': 'a8cb1b014c1b8444c986a318f80becbcf3887dcb',
#      'title': 'The emergence and organization of communicative signals through interaction',
#      'authors': [{'authorId': '2087659410', 'name': 'T. Müller'}]},
#     {'paperId': '01782419e44139042d2a086c9861e7e0bb7c0256',
#      'title': 'An overview of the “Color Game” App project',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'}]},
#     {'paperId': '14ce35d8eddc1d93fc222d8282593a27089bdea1',
#      'title': 'Effect of shared information and owner behavior on showing in dogs (Canis familiaris)',
#      'authors': [{'authorId': '1794498530', 'name': 'Melanie Henschel'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '4558027', 'name': 'J. Bräuer'}]},
#     {'paperId': '7f11542a7af9577e6b3af2359c21262b080ce9e0',
#      'title': 'Cultural evolution of precise and consensual semantic conventions in a multiplayer gaming app',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '144929327', 'name': 'James Winters'}]},
#     {'paperId': 'b27ec0c3f3b6af55519027076aac5c8ea90e3e7e',
#      'title': 'Cultural evolution of precise and consensual semantic conventions in a multiplayer 1 gaming app 2 3',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '144929327', 'name': 'James Winters'}]},
#     {'paperId': 'bee6be0052be692d294faf4ed7b42e6371cfec38',
#      'title': 'Colour terms: native language semantic structure and artificial language structure formation in a large-scale online smartphone application',
#      'authors': [{'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '145281534', 'name': 'I. Noveck'},
#       {'authorId': '49065222', 'name': 'O. Morin'}]},
#     {'paperId': 'c60c42f0fe00c9b7aad134f661d3daa5f6b01363',
#      'title': 'Open Data for the Color Game Project (2018–2019)',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'}]},
#     {'paperId': 'd1ab0adccf0aa251a98fe0f28909bf1bbe61af44',
#      'title': 'The Influence of Shared Visual Context on the Successful Emergence of Conventions in a Referential Communication Task',
#      'authors': [{'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '49065222', 'name': 'O. Morin'}]},
#     {'paperId': '4ac82a4ac4420f0e0847ee8ebed16db084b8282a',
#      'title': 'What smartphone apps may contribute to language evolution research',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '2080906074', 'name': 'Christian Etter'},
#       {'authorId': '2219178', 'name': 'Simon J. Greenhill'}]},
#     {'paperId': 'c2e0142429dea65d53daa25e8c1575b965d8f15a',
#      'title': 'The influence of shared visual context on performance with novel codes in a referential communication game',
#      'authors': [{'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '144929327', 'name': 'James Winters'},
#       {'authorId': '49065222', 'name': 'O. Morin'}]},
#     {'paperId': 'fbefe5693f0ca803e79e9034b8728d75dbc966a4',
#      'title': 'Compression in cultural evolution: Homogeneity and structure in the emergence and evolution of a large-scale online collaborative art project',
#      'authors': [{'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '144929327', 'name': 'James Winters'}]},
#     {'paperId': 'e68cd1afea94860d5029c994a6a6e682a676422c',
#      'title': 'Does shared information predict performance in a referential communication task',
#      'authors': [{'authorId': '49065222', 'name': 'O. Morin'},
#       {'authorId': '2599077', 'name': 'T. Morisseau'},
#       {'authorId': '2087659410', 'name': 'T. Müller'},
#       {'authorId': '152715574', 'name': 'L. Romanova'},
#       {'authorId': '144929327', 'name': 'James Winters'}]}]},
#   {'authorId': '1409754734',
#    'name': 'T. Müller',
#    'papers': [{'paperId': '971f438da217438c529986418f44bcab9de3f4de',
#      'title': 'Cancer among kidney transplant recipients >20 years after transplantation: post-transplant lymphoproliferative disorder remains the most common cancer type in the ultra long-term',
#      'authors': [{'authorId': '2168077674', 'name': 'Julia D Fuhrmann'},
#       {'authorId': '1753320203', 'name': 'Kristyna Valkova'},
#       {'authorId': '7006931', 'name': 'S. von Moos'},
#       {'authorId': '38332562', 'name': 'R. Wüthrich'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '6028241', 'name': 'T. Schachtner'}]},
#     {'paperId': 'a2953a4ae4c2bed1c881341a6e50075bfbe086dd',
#      'title': 'Impact of different urinary tract infection phenotypes within the first year post‐transplant on renal allograft outcomes',
#      'authors': [{'authorId': '51303578', 'name': 'Jakob E Brune'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '9801252', 'name': 'C. Wehmeier'},
#       {'authorId': '49106907', 'name': 'D. Sidler'},
#       {'authorId': '7973321', 'name': 'L. Walti'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '3682979', 'name': 'D. Neofytos'},
#       {'authorId': '3541562', 'name': 'A. Schnyder'},
#       {'authorId': '6001157', 'name': 'K. Boggian'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '6028241', 'name': 'T. Schachtner'},
#       {'authorId': '144622020', 'name': 'N. Khanna'},
#       {'authorId': '47897507', 'name': 'S. Schaub'}]},
#     {'paperId': 'af0d9851a09280376a9a136b49dd148719166d7e',
#      'title': 'Successful Induction of Specific Immunological Tolerance by Combined Kidney and Hematopoietic Stem Cell Transplantation in HLA-Identical Siblings',
#      'authors': [{'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '32234828', 'name': 'K. Hübel'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'},
#       {'authorId': '4316801', 'name': 'I. Abela'},
#       {'authorId': '4363455', 'name': 'A. Gaspert'},
#       {'authorId': '46655776', 'name': 'T. Güngör'},
#       {'authorId': '2151712903', 'name': 'Mathias Hauri'},
#       {'authorId': '4168138', 'name': 'B. Helmchen'},
#       {'authorId': '5521994', 'name': 'C. Linsenmeier'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '48302723', 'name': 'J. Nilsson'},
#       {'authorId': '5645968', 'name': 'O. Riesterer'},
#       {'authorId': '9793694', 'name': 'J. Scandling'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '6719981', 'name': 'P. Cippà'}]},
#     {'paperId': 'b9c3133cdb4d44ad2e47ed734fd4b9464929503e',
#      'title': 'Infection Risk in the First Year After ABO-incompatible Kidney Transplantation: A Nationwide Prospective Cohort Study',
#      'authors': [{'authorId': '4218972', 'name': 'C. Hirzel'},
#       {'authorId': '2161585002', 'name': 'Lea Projer'},
#       {'authorId': '113796465', 'name': 'A. Atkinson'},
#       {'authorId': '113041528', 'name': 'Bernard Surial'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '48642727', 'name': 'Matteo Mombelli'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '6001157', 'name': 'K. Boggian'},
#       {'authorId': '7973321', 'name': 'L. Walti'},
#       {'authorId': '49106907', 'name': 'D. Sidler'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'}]},
#     {'paperId': 'c0e26afc541f46b97e5f930c9e8acad8ad7fb29e',
#      'title': 'Relevance of deceased donor proteinuria for kidney transplantation: A comprehensive national cohort study',
#      'authors': [{'authorId': '120089752', 'name': 'C. Kuhn'},
#       {'authorId': '46984846', 'name': 'A. Born'},
#       {'authorId': '74977725', 'name': 'A. Karolin'},
#       {'authorId': '2055227052', 'name': 'B. Lang'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '1471637107', 'name': 'F. Haidar'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '1421074372', 'name': 'F. Immer'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '49106907', 'name': 'D. Sidler'}]},
#     {'paperId': '02f8e4b77737c444802899b093a1352436fcfb36',
#      'title': 'The MELD upgrade exception: a successful strategy to optimize access to liver transplantation for patients with high waiting list mortality.',
#      'authors': [{'authorId': '12358923', 'name': 'M. Dirchwolf'},
#       {'authorId': '3088896', 'name': 'C. Becchetti'},
#       {'authorId': '2126167988', 'name': 'Sarah Gabriela Gschwend'},
#       {'authorId': '2164219', 'name': 'C. Toso'},
#       {'authorId': '144479812', 'name': 'P. Dutkowski'},
#       {'authorId': '1421074372', 'name': 'F. Immer'},
#       {'authorId': '33281277', 'name': 'Franziska Beyeler'},
#       {'authorId': '51032104', 'name': 'S. Rossi'},
#       {'authorId': '2142315111', 'name': 'Jonas Schropp'},
#       {'authorId': '144692518', 'name': 'J. Dufour'},
#       {'authorId': '2889157', 'name': 'V. Banz'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '2133658478', 'name': 'Andres Axel'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '2133657906', 'name': 'Beckmann Sonja'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '3034884', 'name': 'C. Benden'},
#       {'authorId': '2057291656', 'name': 'Christoph Berger'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '1737814978', 'name': 'Sanda Branca'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '143981435', 'name': 'T. Carrel'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '8390641', 'name': 'S. D. De Geest'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '47937583', 'name': 'J. Dreifuss'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '1398211841', 'name': 'S. Ferrari-Lacraz'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '1404847885', 'name': 'P. Soccal'},
#       {'authorId': '1405443024', 'name': 'Christophe Gaudet'},
#       {'authorId': '4918145', 'name': 'E. Giostra'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '3197116', 'name': 'J. Halter'},
#       {'authorId': '49208842', 'name': 'D. Hauri'},
#       {'authorId': '37851897', 'name': 'D. Heim'},
#       {'authorId': '2052426042', 'name': 'C. Hess'},
#       {'authorId': '6026508', 'name': 'S. Hillinger'},
#       {'authorId': '2061052366', 'name': 'H. Hirsch'},
#       {'authorId': '102434787', 'name': 'P. Hirt'},
#       {'authorId': '153656012', 'name': 'G. Hofbauer'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '2061480781', 'name': 'Michael Koller'},
#       {'authorId': '1404692109', 'name': 'Bettina Laesser'},
#       {'authorId': '89632017', 'name': 'Brian J. Lang'},
#       {'authorId': '145498293', 'name': 'R. Lehmann'},
#       {'authorId': '3085948', 'name': 'A. Leichtle'},
#       {'authorId': '1714035', 'name': 'C. Lovis'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '48262972', 'name': 'H. Marti'},
#       {'authorId': '2110571598', 'name': 'Pierre-Yves Martin'},
#       {'authorId': '46767432', 'name': 'M. Martinelli'},
#       {'authorId': '1949845957', 'name': 'Katell Mellac'},
#       {'authorId': '16027467', 'name': 'A. Merçay'},
#       {'authorId': '2133653308', 'name': 'Karin Mettler'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '2113786601', 'name': 'Antonia Müller'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '2133656385', 'name': 'Ulrike Müller-Arndt'},
#       {'authorId': '4789760', 'name': 'B. Müllhaupt'},
#       {'authorId': '4332063', 'name': 'M. Nägeli'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '1397343031', 'name': 'K. Posfay-Barbe'},
#       {'authorId': '1404577536', 'name': 'J. Rick'},
#       {'authorId': '48739462', 'name': 'A. Rosselet'},
#       {'authorId': '1405145395', 'name': 'Silvia Rothlin'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '3541562', 'name': 'A. Schnyder'},
#       {'authorId': '8222606', 'name': 'M. Schuurmans'},
#       {'authorId': '113308143', 'name': 'F. Simonetta'},
#       {'authorId': '5045690', 'name': 'K. Staufer'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '2133653447', 'name': 'Guido Stirniman'},
#       {'authorId': '119222134', 'name': 'U. Stürzinger'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '113278379', 'name': 'J. Villard'},
#       {'authorId': '3751932', 'name': 'J. Vionnet'},
#       {'authorId': '2058721957', 'name': 'Madeleine Wick'},
#       {'authorId': '2043292449', 'name': 'M. Wilhlem'},
#       {'authorId': '6614629', 'name': 'P. Yerly'}]},
#     {'paperId': '134b042a069839fb3cf96ba80c0321a19b7f6049',
#      'title': 'Outcome of kidney transplantation from very senior donors in Switzerland – a national cohort study',
#      'authors': [{'authorId': '120089752', 'name': 'C. Kuhn'},
#       {'authorId': '143859483', 'name': 'B. Lang'},
#       {'authorId': '2047727151', 'name': 'Sylvia Lörcher'},
#       {'authorId': '74977725', 'name': 'A. Karolin'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '47277338', 'name': 'F. Immer'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '49106907', 'name': 'D. Sidler'}]},
#     {'paperId': '386d48f7e3a1dedbcb57f1fe0311091b17959d16',
#      'title': 'Long-term outcomes of transplant kidneys donated after circulatory death.',
#      'authors': [{'authorId': '2113784659', 'name': 'Amelie Müller'},
#       {'authorId': '2047297219', 'name': 'E. Breuer'},
#       {'authorId': '32234828', 'name': 'K. Hübel'},
#       {'authorId': '40534372', 'name': 'K. Lehmann'},
#       {'authorId': '6719981', 'name': 'P. Cippà'},
#       {'authorId': '6028241', 'name': 'T. Schachtner'},
#       {'authorId': '5771092', 'name': 'C. Oberkofler'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '2148392330', 'name': 'M.P. Weber'},
#       {'authorId': '144479812', 'name': 'P. Dutkowski'},
#       {'authorId': '32491103', 'name': 'P. Clavien'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'}]},
#     {'paperId': '4c73035b957bfa39024834d752ebba062496f58b',
#      'title': 'Infectious complications and graft outcome following treatment of acute antibody-mediated rejection after kidney transplantation: A nationwide cohort study',
#      'authors': [{'authorId': '6572496', 'name': 'N. Perrottet'},
#       {'authorId': '1397739740', 'name': 'M. Fernández-Ruiz'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '12452107', 'name': 'Suzan Dahdal'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '145349941', 'name': 'S. Rotman'},
#       {'authorId': '144950032', 'name': 'S. Moll'},
#       {'authorId': '6316572', 'name': 'H. Hopfer'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '38623396', 'name': 'V. Aubert'},
#       {'authorId': '2298897', 'name': 'L. Bühler'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'}]},
#     {'paperId': 'ab95ab88b0a8e59b675007845fef16c772bd7081',
#      'title': 'Pre‐transplant donor‐specific HLA antibodies and risk for poor first‐year renal transplant outcomes: results from the Swiss Transplant Cohort Study',
#      'authors': [{'authorId': '9801252', 'name': 'C. Wehmeier'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '49106907', 'name': 'D. Sidler'},
#       {'authorId': '6623056', 'name': 'U. Wirthmüller'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '1398211841', 'name': 'S. Ferrari-Lacraz'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '38623396', 'name': 'V. Aubert'},
#       {'authorId': '3541562', 'name': 'A. Schnyder'},
#       {'authorId': '13394344', 'name': 'K. Šunić'},
#       {'authorId': '6028241', 'name': 'T. Schachtner'},
#       {'authorId': '48302723', 'name': 'J. Nilsson'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '2133658478', 'name': 'Andres Axel'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '2889157', 'name': 'V. Banz'},
#       {'authorId': '2133657906', 'name': 'Beckmann Sonja'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3753376', 'name': 'E. Berishvili'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '1737814978', 'name': 'Sanda Branca'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '152248899', 'name': 'T. Carrel'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '8390641', 'name': 'S. D. De Geest'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '47937583', 'name': 'J. Dreifuss'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '48140393', 'name': 'N. Franscini'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '1404847885', 'name': 'P. Soccal'},
#       {'authorId': '1405443024', 'name': 'Christophe Gaudet'},
#       {'authorId': '104993763', 'name': 'N. Goossens'},
#       {'authorId': '3197116', 'name': 'J. Halter'},
#       {'authorId': '37851897', 'name': 'D. Heim'},
#       {'authorId': '4044250', 'name': 'C. Hess'},
#       {'authorId': '6026508', 'name': 'S. Hillinger'},
#       {'authorId': '2061052366', 'name': 'H. Hirsch'},
#       {'authorId': '2092801888', 'name': 'P. Hirt'},
#       {'authorId': '153656012', 'name': 'G. Hofbauer'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '1421074372', 'name': 'F. Immer'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '8793657', 'name': 'Mirjam Laager'},
#       {'authorId': '1404692109', 'name': 'Bettina Laesser'},
#       {'authorId': '145498293', 'name': 'R. Lehmann'},
#       {'authorId': '3085948', 'name': 'A. Leichtle'},
#       {'authorId': '1714035', 'name': 'C. Lovis'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '48262972', 'name': 'H. Marti'},
#       {'authorId': '2110571598', 'name': 'Pierre-Yves Martin'},
#       {'authorId': '46767432', 'name': 'M. Martinelli'},
#       {'authorId': '1937911', 'name': 'V. McLin'},
#       {'authorId': '1949845957', 'name': 'Katell Mellac'},
#       {'authorId': '16027467', 'name': 'A. Merçay'},
#       {'authorId': '2133653308', 'name': 'Karin Mettler'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '144286443', 'name': 'A. Müller'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '2133656385', 'name': 'Ulrike Müller-Arndt'},
#       {'authorId': '4789760', 'name': 'B. Müllhaupt'},
#       {'authorId': '4332063', 'name': 'M. Nägeli'},
#       {'authorId': '6908022', 'name': 'G. Oldani'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '1397343031', 'name': 'K. Posfay-Barbe'},
#       {'authorId': '1404577536', 'name': 'J. Rick'},
#       {'authorId': '48739462', 'name': 'A. Rosselet'},
#       {'authorId': '51032104', 'name': 'S. Rossi'},
#       {'authorId': '1405145395', 'name': 'Silvia Rothlin'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '8222606', 'name': 'M. Schuurmans'},
#       {'authorId': '2510671', 'name': 'T. Sengstag'},
#       {'authorId': '113308143', 'name': 'F. Simonetta'},
#       {'authorId': '5045690', 'name': 'K. Staufer'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '2133653447', 'name': 'Guido Stirniman'},
#       {'authorId': '119222134', 'name': 'U. Stürzinger'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '113278379', 'name': 'J. Villard'},
#       {'authorId': '3751932', 'name': 'J. Vionnet'},
#       {'authorId': '2058721957', 'name': 'Madeleine Wick'},
#       {'authorId': '2043292449', 'name': 'M. Wilhlem'},
#       {'authorId': '6614629', 'name': 'P. Yerly'}]},
#     {'paperId': 'b23c683a7643e4a0ad6cccdb60afeb0bf262314e',
#      'title': 'Demographic, psychosocial and health disparities between living and deceased renal allograft recipients in Switzerland.',
#      'authors': [{'authorId': '35244389', 'name': 'R. Achermann'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '8390641', 'name': 'S. D. De Geest'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '52148358', 'name': 'A. Kiss'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': None,
#        'name': 'The Psychosocial Interest Group And The Swiss Tran'}]},
#     {'paperId': '2c7cf847ef5389bdeb40e65aa24271dab525e9ca',
#      'title': 'Dialysis after graft loss: a Swiss experience.',
#      'authors': [{'authorId': '6118895', 'name': 'M. Bonani'},
#       {'authorId': '35244389', 'name': 'R. Achermann'},
#       {'authorId': '48015680', 'name': 'H. Seeger'},
#       {'authorId': '26595608', 'name': 'M. Scharfe'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '12452107', 'name': 'Suzan Dahdal'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '38332562', 'name': 'R. Wüthrich'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '5546042', 'name': 'S. Segerer'}]},
#     {'paperId': '4801d79d77a467501f68989c1bcbd836dfc73098',
#      'title': 'P1639DEVELOPMENT OF SELF-LIMITED LOW-LEVEL BK VIREMIA/VIRURIA SUGGESTS IDEAL IMMUNOSUPPRESSION TO SUPPRESS T-CELL AND ANTIBODY-MEDIATED REJECTION AND PRESERVE KIDNEY ALLOGRAFT FUNCTION',
#      'authors': [{'authorId': '46682587', 'name': 'Bettina Näf'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '3638777', 'name': 'R. P. Wuthrich'},
#       {'authorId': '6028241', 'name': 'T. Schachtner'}]},
#     {'paperId': '9e1cc3c44800147dca0520a63c830255f417e36b',
#      'title': 'First experience of SARS-CoV-2 infections in solid organ transplant recipients in the Swiss Transplant Cohort Study',
#      'authors': [{'authorId': '1474421780', 'name': 'J. Tschopp'},
#       {'authorId': '1401026888', 'name': "A. L'Huillier"},
#       {'authorId': '48642727', 'name': 'Matteo Mombelli'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '144622020', 'name': 'N. Khanna'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '11688012', 'name': 'D. Meloni'},
#       {'authorId': '1399685171', 'name': 'M. Papadimitriou-Olivgeris'},
#       {'authorId': '3682979', 'name': 'D. Neofytos'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '8222606', 'name': 'M. Schuurmans'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '144756268', 'name': 'T. Berney'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '7828323', 'name': 'C. Delden'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '2889157', 'name': 'V. Banz'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '3034884', 'name': 'C. Benden'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '1737814978', 'name': 'Sanda Branca'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '115551922', 'name': 'Thierry Carell'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '6567694', 'name': 'S. Geest'},
#       {'authorId': '8734195', 'name': 'O. Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '4071822', 'name': 'L. Elkrief'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '1398211841', 'name': 'S. Ferrari-Lacraz'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '1404847885', 'name': 'P. Soccal'},
#       {'authorId': '1405443024', 'name': 'Christophe Gaudet'},
#       {'authorId': '4918145', 'name': 'E. Giostra'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '3197116', 'name': 'J. Halter'},
#       {'authorId': '49208842', 'name': 'D. Hauri'},
#       {'authorId': '37851897', 'name': 'D. Heim'},
#       {'authorId': '4044250', 'name': 'C. Hess'},
#       {'authorId': '6026508', 'name': 'S. Hillinger'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '153656012', 'name': 'G. Hofbauer'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '1421074372', 'name': 'F. Immer'},
#       {'authorId': '6018743', 'name': 'R. Klaghofer'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '1404692109', 'name': 'Bettina Laesser'},
#       {'authorId': '2052663', 'name': 'G. Laube'},
#       {'authorId': '145498293', 'name': 'R. Lehmann'},
#       {'authorId': '1714035', 'name': 'C. Lovis'},
#       {'authorId': '4380049', 'name': 'P. Majno'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '48262972', 'name': 'H. Marti'},
#       {'authorId': '2110571598', 'name': 'Pierre-Yves Martin'},
#       {'authorId': '46767422', 'name': 'M. Martinelli'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '144286443', 'name': 'A. Müller'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '4789760', 'name': 'B. Müllhaupt'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '7003997', 'name': 'J. Passweg'},
#       {'authorId': '1397343031', 'name': 'K. Posfay-Barbe'},
#       {'authorId': '1404577536', 'name': 'J. Rick'},
#       {'authorId': '5451444', 'name': 'E. Roosnek'},
#       {'authorId': '48739462', 'name': 'A. Rosselet'},
#       {'authorId': '1405145395', 'name': 'Silvia Rothlin'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '3541562', 'name': 'A. Schnyder'},
#       {'authorId': '8222606', 'name': 'M. Schuurmans'},
#       {'authorId': '2697027', 'name': 'C. Seiler'},
#       {'authorId': '1740654359', 'name': 'Jan Sprachta'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '48376679', 'name': 'C. Steinack'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '3702609', 'name': 'G. Stirnimann'},
#       {'authorId': '2164219', 'name': 'C. Toso'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '113278379', 'name': 'J. Villard'},
#       {'authorId': '2058721957', 'name': 'Madeleine Wick'},
#       {'authorId': '2995466', 'name': 'M. Wilhelm'},
#       {'authorId': '6614629', 'name': 'P. Yerly'}]},
#     {'paperId': 'c4f2c29c04e94f8094ce9230b9b63a6e9c984403',
#      'title': 'Burden and Timeline of Infectious Diseases in the First Year After Solid Organ Transplantation in the Swiss Transplant Cohort Study',
#      'authors': [{'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '6406449', 'name': 'A. Cusini'},
#       {'authorId': '4218972', 'name': 'C. Hirzel'},
#       {'authorId': '144622020', 'name': 'N. Khanna'},
#       {'authorId': '2374049', 'name': 'M. Weisser'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '1405185282', 'name': 'K. Boggian'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3866203', 'name': 'D. Nadal'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '5719767', 'name': 'R. Saccilotto'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '2889157', 'name': 'V. Banz'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '3034884', 'name': 'C. Benden'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '1737814978', 'name': 'Sanda Branca'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '115551922', 'name': 'Thierry Carell'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '8390641', 'name': 'S. D. De Geest'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '4071822', 'name': 'L. Elkrief'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '1398211841', 'name': 'S. Ferrari-Lacraz'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '2128071830', 'name': 'Paola Gasche Soccal'},
#       {'authorId': '1405443024', 'name': 'Christophe Gaudet'},
#       {'authorId': '4918145', 'name': 'E. Giostra'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '3197116', 'name': 'J. Halter'},
#       {'authorId': '49208842', 'name': 'D. Hauri'},
#       {'authorId': '37851897', 'name': 'D. Heim'},
#       {'authorId': '4044250', 'name': 'C. Hess'},
#       {'authorId': '6026508', 'name': 'S. Hillinger'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '153656012', 'name': 'G. Hofbauer'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '1421074372', 'name': 'F. Immer'},
#       {'authorId': '6018743', 'name': 'R. Klaghofer'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '1404692109', 'name': 'Bettina Laesser'},
#       {'authorId': '2052663', 'name': 'G. Laube'},
#       {'authorId': '145498293', 'name': 'R. Lehmann'},
#       {'authorId': '1714035', 'name': 'C. Lovis'},
#       {'authorId': '4380049', 'name': 'P. Majno'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '48262972', 'name': 'H. Marti'},
#       {'authorId': '2128070882', 'name': 'Pierre Yves Martin'},
#       {'authorId': '46767432', 'name': 'M. Martinelli'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '144286443', 'name': 'A. Müller'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '4789760', 'name': 'B. Müllhaupt'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '7003997', 'name': 'J. Passweg'},
#       {'authorId': '1397343031', 'name': 'K. Posfay-Barbe'},
#       {'authorId': '1404577536', 'name': 'J. Rick'},
#       {'authorId': '5451444', 'name': 'E. Roosnek'},
#       {'authorId': '48739462', 'name': 'A. Rosselet'},
#       {'authorId': '1405145395', 'name': 'Silvia Rothlin'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '3541562', 'name': 'A. Schnyder'},
#       {'authorId': '2697027', 'name': 'C. Seiler'},
#       {'authorId': '1740654359', 'name': 'Jan Sprachta'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '3702609', 'name': 'G. Stirnimann'},
#       {'authorId': '2164219', 'name': 'C. Toso'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '113278379', 'name': 'J. Villard'},
#       {'authorId': '2058721957', 'name': 'Madeleine Wick'},
#       {'authorId': '48926701', 'name': 'Markus Wilhelm'},
#       {'authorId': '6614629', 'name': 'P. Yerly'}]},
#     {'paperId': '9acbf345cdf1d54a3bf4eff45fc1961dfe560c9a',
#      'title': '51ST ANNUAL MEETING OF THE SWISS SOCIETY OF NEPHROLOGY (SGN-SSN)',
#      'authors': [{'authorId': '74977725', 'name': 'A. Karolin'},
#       {'authorId': '2087800865', 'name': 'Ms. Divya Thottan'},
#       {'authorId': '2101507340', 'name': 'Julia Zinsli'},
#       {'authorId': '47750371', 'name': 'D. Stefan'},
#       {'authorId': '2104795553', 'name': 'Rudolff'},
#       {'authorId': '2081968888', 'name': 'Dr. Michael Koller'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '1580378307', 'name': 'D. Vanessa'},
#       {'authorId': '29996382', 'name': 'Banz'},
#       {'authorId': '12619517', 'name': 'Berney Thierry'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '2081580780', 'name': 'Dr. Patrizia Amico'},
#       {'authorId': '2057304339', 'name': 'Dr. Isabelle Binet'},
#       {'authorId': '49106907', 'name': 'D. Sidler'},
#       {'authorId': '1478876659', 'name': 'A. Sassi'},
#       {'authorId': '2102228308', 'name': 'Ms. Alexandra Chassot'},
#       {'authorId': '4431052', 'name': 'E. Hummler'},
#       {'authorId': '4071336', 'name': 'E. Feraille'},
#       {'authorId': '2057793247', 'name': 'Ms. Hannah Black'}]},
#     {'paperId': 'd5f455da2408d51dfa3337aaea5f52846f10bd33',
#      'title': 'Vaccination Status in Pediatric Solid-Organ Transplant Recipients and Their Household Members.',
#      'authors': [{'authorId': '31426956', 'name': 'G. Cortina'},
#       {'authorId': '5597442', 'name': 'V. Ojinaga'},
#       {'authorId': '4790972', 'name': 'M. Zlamy'},
#       {'authorId': '4057077', 'name': 'T. Giner'},
#       {'authorId': '5344373', 'name': 'M. Riedl'},
#       {'authorId': '3745192', 'name': 'M. Rauchenzauner'},
#       {'authorId': '4232247', 'name': 'A. Entenmann'},
#       {'authorId': '1409754734', 'name': 'T. Müller'}]},
#     {'paperId': '44b21a3164be44709c7558fcd1576700f5932c72',
#      'title': 'SP695DIALYSIS AFTER GRAFT LOSS: THE SWISS EXPERIENCE',
#      'authors': [{'authorId': '6118895', 'name': 'M. Bonani'},
#       {'authorId': '35244389', 'name': 'R. Achermann'},
#       {'authorId': '48015680', 'name': 'H. Seeger'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '12452107', 'name': 'Suzan Dahdal'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '38332562', 'name': 'R. Wüthrich'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '5546042', 'name': 'S. Segerer'}]},
#     {'paperId': '5e43fbb8171ead068cc0a243ff36e474dd50b2fd',
#      'title': 'Preservation of kidney function in kidney transplant recipients by alkali therapy (Preserve-Transplant Study): rationale and study protocol',
#      'authors': [{'authorId': '48135483', 'name': 'A. Wiegand'},
#       {'authorId': '47464518', 'name': 'Alexander Ritter'},
#       {'authorId': '48567357', 'name': 'N. Graf'},
#       {'authorId': '4439107', 'name': 'S. Arampatzis'},
#       {'authorId': '49106907', 'name': 'D. Sidler'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '2082672865', 'name': 'Carsten A. Wagner'},
#       {'authorId': '38332562', 'name': 'R. Wüthrich'},
#       {'authorId': '6994960', 'name': 'N. Mohebbi'}]},
#     {'paperId': '01bf9c037a4e01ddd7e125b081c41f6d304d05b8',
#      'title': 'Rapid adaptation drives invasion of airway donor microbiota by Pseudomonas after lung transplantation',
#      'authors': [{'authorId': '3884848', 'name': 'M. Beaume'},
#       {'authorId': '145236469', 'name': 'T. Köhler'},
#       {'authorId': '5936890', 'name': 'Gilbert GREUB'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '6936642', 'name': 'L. Baerlocher'},
#       {'authorId': '1764925', 'name': 'L. Farinelli'},
#       {'authorId': '5533082', 'name': 'A. Buckling'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': None,
#        'name': 'Rita Patrizia Philippe Guido Christian Christoph Isabel Achermann Amico Baumann Beldi Benden Berger Binet '},
#       {'authorId': '35244389', 'name': 'R. Achermann'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '2105525889', 'name': 'Philippe Baumann'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '3034884', 'name': 'C. Benden'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '6885495', 'name': 'E. Boely'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '2298897', 'name': 'L. Bühler'},
#       {'authorId': '115551922', 'name': 'Thierry Carell'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '6567694', 'name': 'S. Geest'},
#       {'authorId': '8734195', 'name': 'O. Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
#       {'authorId': '1398211841', 'name': 'S. Ferrari-Lacraz'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '1404847885', 'name': 'P. Soccal'},
#       {'authorId': '4918145', 'name': 'E. Giostra'},
#       {'authorId': '4096637', 'name': 'D. Golshayan'},
#       {'authorId': '104379003', 'name': 'D. Good'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '3197116', 'name': 'J. Halter'},
#       {'authorId': '37851897', 'name': 'D. Heim'},
#       {'authorId': '4044250', 'name': 'C. Hess'},
#       {'authorId': '6026508', 'name': 'S. Hillinger'},
#       {'authorId': '35171926', 'name': 'H. Hirsch'},
#       {'authorId': '37273220', 'name': 'G. Hofbauer'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '47277338', 'name': 'F. Immer'},
#       {'authorId': '6018743', 'name': 'R. Klaghofer'},
#       {'authorId': '144189024', 'name': 'M. Koller'},
#       {'authorId': '1404692109', 'name': 'Bettina Laesser'},
#       {'authorId': '39850433', 'name': 'R. Lehmann'},
#       {'authorId': '1714035', 'name': 'C. Lovis'},
#       {'authorId': '48262972', 'name': 'H. Marti'},
#       {'authorId': '115350821', 'name': 'Pierre-Yves Martin'},
#       {'authorId': '4893660', 'name': 'L. Martinolli'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '4432601', 'name': 'P. Mohacsi'},
#       {'authorId': '5298469', 'name': 'I. Morard'},
#       {'authorId': '39153734', 'name': 'P. Morel'},
#       {'authorId': '1404517478', 'name': 'Ulrike Mueller'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '1405145344', 'name': 'Helen Mueller-McKenna'},
#       {'authorId': '144286443', 'name': 'A. Müller'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '4789760', 'name': 'B. Müllhaupt'},
#       {'authorId': '3866203', 'name': 'D. Nadal'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '7003997', 'name': 'J. Passweg'},
#       {'authorId': '118413943', 'name': 'Chantal Piot Ziegler'},
#       {'authorId': '1404577536', 'name': 'J. Rick'},
#       {'authorId': '5451444', 'name': 'E. Roosnek'},
#       {'authorId': '48739462', 'name': 'A. Rosselet'},
#       {'authorId': '1405145395', 'name': 'Silvia Rothlin'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '4920834', 'name': 'U. Schanz'},
#       {'authorId': '47897507', 'name': 'S. Schaub'},
#       {'authorId': '48746079', 'name': 'C. Seiler'},
#       {'authorId': '3899227', 'name': 'S. Stampf'},
#       {'authorId': '3697554', 'name': 'J. Steiger'},
#       {'authorId': '3702609', 'name': 'G. Stirnimann'},
#       {'authorId': '2164219', 'name': 'C. Toso'},
#       {'authorId': '48266107', 'name': 'D. Tsinalis'},
#       {'authorId': '6085296', 'name': 'J. Venetz'},
#       {'authorId': '113278379', 'name': 'J. Villard'},
#       {'authorId': '2058721957', 'name': 'Madeleine Wick'},
#       {'authorId': '2995466', 'name': 'M. Wilhelm'},
#       {'authorId': '6614629', 'name': 'P. Yerly'}]},
#     {'paperId': '06700d378a97a10cd52f265f5e81fae65b2ef2f1',
#      'title': 'Early complications after living donor nephrectomy: analysis of the Swiss Organ Living Donor Health Registry.',
#      'authors': [{'authorId': '6530382', 'name': 'F. Burkhalter'},
#       {'authorId': '1397327701', 'name': 'U. Huynh-Do'},
#       {'authorId': '4478612', 'name': 'K. Hadaya'},
#       {'authorId': '144592803', 'name': 'M. Matter'},
#       {'authorId': '1409754734', 'name': 'T. Müller'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4631441', 'name': 'C. Nolte'},
#       {'authorId': '50165323', 'name': 'J. Steiger'}]},
#     {'paperId': '68b164c05fe6dac5ed595725078106f2ef8f0df7',
#      'title': 'Ventricular assist devices as bridge to heart transplantation: impact on post-transplant infections',
#      'authors': [{'authorId': '6068620', 'name': 'D. Héquet'},
#       {'authorId': '1737830306', 'name': 'G. Kralidis'},
#       {'authorId': '143981435', 'name': 'T. Carrel'},
#       {'authorId': '6406449', 'name': 'A. Cusini'},
#       {'authorId': '7013289', 'name': 'C. Garzoni'},
#       {'authorId': '47836169', 'name': 'R. Hullin'},
#       {'authorId': '4180528', 'name': 'P. Meylan'},
#       {'authorId': '4432601', 'name': 'P. Mohacsi'},
#       {'authorId': '37300377', 'name': 'N. Mueller'},
#       {'authorId': '4347627', 'name': 'F. Ruschitzka'},
#       {'authorId': '3665958', 'name': 'P. Tozzi'},
#       {'authorId': '145379728', 'name': 'C. van Delden'},
#       {'authorId': '2374049', 'name': 'M. Weisser'},
#       {'authorId': '2995466', 'name': 'M. Wilhelm'},
#       {'authorId': '143963448', 'name': 'M. Pascual'},
#       {'authorId': '3596797', 'name': 'O. Manuel'},
#       {'authorId': None,
#        'name': 'Rita Patrizia John-David Philippe Guido Christian Chris Achermann Amico Aubert Baumann Beldi Benden Berger'},
#       {'authorId': '35244389', 'name': 'R. Achermann'},
#       {'authorId': '35234181', 'name': 'P. Amico'},
#       {'authorId': '145208876', 'name': 'J. Aubert'},
#       {'authorId': '2105525889', 'name': 'Philippe Baumann'},
#       {'authorId': '1707776', 'name': 'G. Beldi'},
#       {'authorId': '3034884', 'name': 'C. Benden'},
#       {'authorId': '144421277', 'name': 'C. Berger'},
#       {'authorId': '3605316', 'name': 'I. Binet'},
#       {'authorId': '4105101', 'name': 'P. Bochud'},
#       {'authorId': '6885495', 'name': 'E. Boely'},
#       {'authorId': '6447318', 'name': 'H. Bucher'},
#       {'authorId': '2157458529', 'name': 'L. Bühler'},
#       {'authorId': '115551922', 'name': 'Thierry Carell'},
#       {'authorId': '1405145482', 'name': 'Emmanuelle Catana'},
#       {'authorId': '5789670', 'name': 'Y. Chalandon'},
#       {'authorId': '8390641', 'name': 'S. D. De Geest'},
#       {'authorId': '3557296', 'name': 'O. de Rougemont'},
#       {'authorId': '5596062', 'name': 'M. Dickenmann'},
#       {'authorId': '6025506', 'name': 'M. Duchosal'},
#       {'authorId': '4071822', 'name': 'L. Elkrief'},
#       {'authorId': '144101593', 'name': 'T. Fehr'},
# ...
#     {'paperId': 'b93e0594e75ccf668d6f9b7cdf7cda3f60e3ea8e',
#      'title': 'Plasmapheresis in fatal overdose with verapamil',
#      'authors': [{'authorId': '2071215472', 'name': 'U. Kuhlmann'},
#       {'authorId': '2452572', 'name': 'H. Schoenemann'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '50739777', 'name': 'M. Keuchel'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'd23821c551a2523458c9fd3300eb2137be751471',
#      'title': 'Immediate and long-term results of ATG induction therapy for delayed graft function compared to conventional therapy for immediate graft function',
#      'authors': [{'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '2071215472', 'name': 'U. Kuhlmann'},
#       {'authorId': '36666252', 'name': 'S. Grebe'},
#       {'authorId': '5206739', 'name': 'J. Heymanns'},
#       {'authorId': '1397443307', 'name': 'H. Feiber'},
#       {'authorId': '6613179', 'name': 'H. Riedmiller'}]},
#     {'paperId': '3a6725cf90d67acddec6cc2835298008ef090f2e',
#      'title': 'Neopterin, Serum Amyloid A, and Cytokine Monitoring After Renal Transplantation',
#      'authors': [{'authorId': '80501081', 'name': 'M. Neumann'},
#       {'authorId': '47809438', 'name': 'H. Sprenger'},
#       {'authorId': '36666252', 'name': 'S. Grebe'},
#       {'authorId': '116348652', 'name': 'D. Gemsa'},
#       {'authorId': '2310111', 'name': 'G. Reibnegger'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '152456175', 'name': 'T. Müller'}]},
#     {'paperId': '719727cdd74fe69afd17fc32930ba7d47c0ef0da',
#      'title': 'Noninvasive monitoring using serum amyloid A and serum neopterin in cardiac transplantation.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '103412590', 'name': 'M. Vogl'},
#       {'authorId': '80501081', 'name': 'M. Neumann'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '2073296948', 'name': 'M. Grimm'},
#       {'authorId': '2107206227', 'name': 'M. Müller'}]},
#     {'paperId': '731faf7c1b70b78f46f597f8764ac09ed04754d4',
#      'title': 'Biocompatibility Differences with Respect to the Dialyzer Sterilization Method',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '151474532', 'name': 'M. Seitz'},
#       {'authorId': '6757898', 'name': 'I. Eckle'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '153760886', 'name': 'G. Kolb'}]},
#     {'paperId': '2af55a20e1730fc20416ef96adca5334ec0ec524',
#      'title': '25 LONG-TERM EFFECTS OF ANTI-THYMOCYTE GLOBULINS ON LYMPHOCYTE SUBSETS',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '11494567', 'name': 'B. Reckzeh'},
#       {'authorId': '2078356026', 'name': 'A. Borutta'},
#       {'authorId': '36666252', 'name': 'S. Grebe'},
#       {'authorId': '5977691', 'name': 'K. Radsak'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': '3deb72d82f89b9b9e227b31a54301576d02dd80c',
#      'title': 'Pancreas-specific protein (PASP), serum amyloid A (SAA), and neopterin (NEOP) in the diagnosis of rejection after simultaneous pancreas and kidney transplantation',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '47671055', 'name': 'F. Trösch'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '50154208', 'name': 'R. Grüssner'},
#       {'authorId': '1397443307', 'name': 'H. Feiber'},
#       {'authorId': '48182961', 'name': 'B. Göke'},
#       {'authorId': '46467316', 'name': 'B. Greger'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': '622c1a02b646bd7d9bc58db3fb9dd44978e4d5fb',
#      'title': 'Detection of renal allograft rejection by complement components C5A and TCC in plasma and urine.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '47311224', 'name': 'M. Kraus'},
#       {'authorId': '1992578705', 'name': 'C. Neumann'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'cf3c45070d2a5cdc1092f5c71eac3fe5c161ceea',
#      'title': 'Pancreas‐specific protein (PASP), serum amyloid A [SAA), and neopterin (NEOP) in the diagnosis of rejection after simultaneous pancreas and kidney transplantation',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '47671055', 'name': 'F. Trösch'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '50154208', 'name': 'R. Grüssner'},
#       {'authorId': '46467316', 'name': 'B. Greger'},
#       {'authorId': '1397443307', 'name': 'H. Feiber'},
#       {'authorId': '48182961', 'name': 'B. Göke'}]},
#     {'paperId': 'd4043aec472bf9fb36dfb7aa39643425b8a39d44',
#      'title': 'Persistent long-term changes in lymphocyte subsets induced by polyclonal antibodies.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '36666252', 'name': 'S. Grebe'},
#       {'authorId': '80501081', 'name': 'M. Neumann'},
#       {'authorId': '5206739', 'name': 'J. Heymanns'},
#       {'authorId': '5977691', 'name': 'K. Radsak'},
#       {'authorId': '47809438', 'name': 'H. Sprenger'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'a0c3a84fb6accf6505c813b381369bd05087d471',
#      'title': 'The influence of the immunosuppressants OKT3 and ATG on immunological parameters.',
#      'authors': [{'authorId': '80501081', 'name': 'M. Neumann'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '47809438', 'name': 'H. Sprenger'},
#       {'authorId': '116348652', 'name': 'D. Gemsa'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'd9abf0b660624763a9a6654200a6456416ccbf0c',
#      'title': 'Correlation between transplant-coordinator activities and donor availability: a retrospective region analysis.',
#      'authors': [{'authorId': '14343279', 'name': 'L. Viorescu'},
#       {'authorId': '47917470', 'name': 'U. Heck'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': '529468ef11dd5277cc3b28a86cb420ee4ea4d445',
#      'title': 'Immediate metabolic effects of different nutritional regimens in critically ill medical patients',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '2113785809', 'name': 'A. Müller'},
#       {'authorId': '2077147465', 'name': 'M. Bachem'},
#       {'authorId': '2053155086', 'name': 'H. Lange'}]},
#     {'paperId': '7dc0525763d785be17b83ce6c72120e970b74af1',
#      'title': 'Granulocyte-monocyte colony-stimulating factor levels during hemodialysis-induced leukopenia.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '13456852', 'name': 'M. Klausmann'},
#       {'authorId': '6757898', 'name': 'I. Eckle'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': '78aced73a72a38cf1dcc4ca523efcb3b9cdbfbac',
#      'title': 'Hemophan versus hemophan--a philippic against the suggestion of constant membrane quality.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '3198621', 'name': 'H. Höffken'},
#       {'authorId': '77302474', 'name': 'K. Joseph'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': '9021dcabe08acbfc99c2ec7499f645287bb6d1c8',
#      'title': '[A comparative study of the plasma amyloid A level as well as of 9 other parameters in allograft rejection].',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '74074195', 'name': 'S. Schindler'},
#       {'authorId': '49817427', 'name': 'A. Steinmetz'},
#       {'authorId': '7526867', 'name': 'G. Hocke'},
#       {'authorId': '115833292', 'name': 'J. Beck'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '116348652', 'name': 'D. Gemsa'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'adabbf5f7a416a9f1ccb2b4d455ed9c8fed849c0',
#      'title': 'Prospective analysis of 10 different parameters of acute renal allograft rejection.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '74074195', 'name': 'S. Schindler'},
#       {'authorId': '47809438', 'name': 'H. Sprenger'},
#       {'authorId': '49817427', 'name': 'A. Steinmetz'},
#       {'authorId': '7526867', 'name': 'G. Hocke'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '116348652', 'name': 'D. Gemsa'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'eef7276b34fb4fa3695d4936ac752fe605561c3a',
#      'title': 'Diagnosis of viral infections under therapy with OKT3 and antithymocyte globulin.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '47809438', 'name': 'H. Sprenger'},
#       {'authorId': '50739777', 'name': 'M. Keuchel'},
#       {'authorId': '1992578705', 'name': 'C. Neumann'},
#       {'authorId': '145139784', 'name': 'H. Ebel'},
#       {'authorId': '116348652', 'name': 'D. Gemsa'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'a074c00efd34534d0e528a4aeb37afd45febec5a',
#      'title': '[Differential diagnosis of transplant function disorders in therapy with monoclonal antibodies OKT3].',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '50739777', 'name': 'M. Keuchel'},
#       {'authorId': '74074195', 'name': 'S. Schindler'},
#       {'authorId': '49817427', 'name': 'A. Steinmetz'},
#       {'authorId': '1397443307', 'name': 'H. Feiber'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'ce003c6ab1bfbf1cf6eec5ba4994b0c8265662f0',
#      'title': 'The role of membrane contact in hemodialysis-induced granulocyte activation.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '13034508', 'name': 'C. Nolting'},
#       {'authorId': '6757898', 'name': 'I. Eckle'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': 'e3018175171798e65c194fd99ccef4508625476a',
#      'title': 'Hemodialysis and blood coagulation: the effect of hemodialysis on coagulation factor XIII and thrombin-antithrombin III complex.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '2057397049', 'name': 'W. Fischer'},
#       {'authorId': '145759521', 'name': 'R. Seitz'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '7142141', 'name': 'R. Egbring'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': '208289442a4744d7049d311b45a7372f31055153',
#      'title': 'Detection of cytomegalovirus infection under therapy with OKT3 monoclonal antibodies.',
#      'authors': [{'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '48672155', 'name': 'S. Tolle'},
#       {'authorId': '50739777', 'name': 'M. Keuchel'},
#       {'authorId': '74074195', 'name': 'S. Schindler'},
#       {'authorId': '7526867', 'name': 'G. Hocke'},
#       {'authorId': '49817427', 'name': 'A. Steinmetz'},
#       {'authorId': '115833292', 'name': 'J. Beck'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': '3cba47fb01829fcb79213c59305ea696ce425c7a',
#      'title': 'Kinetics of Pulmonary Leukocyte Sequestration in Man during Hemodialysis with Different Membrane-Types',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '3198621', 'name': 'H. Höffken'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '4217566', 'name': 'K. Havemann'},
#       {'authorId': '77302474', 'name': 'K. Joseph'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': '80b8f51cd09d9be0278c8806b00d1cf86af2856e',
#      'title': 'Latent inhibition of granulocyte function by cyclosporine A.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '6757898', 'name': 'I. Eckle'},
#       {'authorId': '2228032', 'name': 'K. Bittner'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '4217566', 'name': 'K. Havemann'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]},
#     {'paperId': 'c5220f61ba9bcc82989c7fc56dea3f02af41cab1',
#      'title': 'Membrane dependent pulmonary sequestration of leukocytes during hemodialysis.',
#      'authors': [{'authorId': '3198621', 'name': 'H. Höffken'},
#       {'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '77302474', 'name': 'K. Joseph'},
#       {'authorId': '4217566', 'name': 'K. Havemann'},
#       {'authorId': '2059587929', 'name': 'K. Lange'}]},
#     {'paperId': '7cd15e14e24778eac104b00d3e925105f3330f11',
#      'title': 'Granulocyte-related bioincompatibility of hemodialysis: inhibition of oxidative metabolism, degranulation reaction, enzyme release and leukocyte sequestration in the lung.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '2057397049', 'name': 'W. Fischer'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '3198621', 'name': 'H. Höffken'},
#       {'authorId': '77302474', 'name': 'K. Joseph'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': 'bd65aafdfb4ee592c689b6726dd010e834e96dda',
#      'title': 'Effect of cuprophan, hemophan and polysulfone membranes on the oxidative metabolism, degranulation reaction, enzyme release and pulmonary sequestration of granulocytes.',
#      'authors': [{'authorId': '153760886', 'name': 'G. Kolb'},
#       {'authorId': '2057397049', 'name': 'W. Fischer'},
#       {'authorId': '2452572', 'name': 'H. Schoenemann'},
#       {'authorId': '8195933', 'name': 'K. Bathke'},
#       {'authorId': '3198621', 'name': 'H. Höffken'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '40414534', 'name': 'H. Lange'},
#       {'authorId': '77302474', 'name': 'K. Joseph'},
#       {'authorId': '4217566', 'name': 'K. Havemann'}]},
#     {'paperId': '032a6299308939ff5652295d61f0b4ba17cd862c',
#      'title': 'Computer Aided Decision Support for Post-Transplant Renal Allograft Rejection',
#      'authors': [{'authorId': '2151398212', 'name': 'H. Müller'},
#       {'authorId': '152456175', 'name': 'T. Müller'},
#       {'authorId': '1997160341', 'name': 'C. Lohrengel'},
#       {'authorId': '40414534', 'name': 'H. Lange'}]}]},
#   {'authorId': '143664985',
#    'name': 'M. Thomas',
#    'papers': [{'paperId': '9a76a350218bfd42a975203080c867a1940fc503',
#      'title': 'Catheter ablation of left atrial macroreentrant tachycardia after bilateral lung transplantation',
#      'authors': [{'authorId': '31475510', 'name': 'Fu Guan'},
#       {'authorId': '2051748', 'name': 'G. Suna'},
#       {'authorId': '143664985', 'name': 'M. Thomas'},
#       {'authorId': '5047651', 'name': 'I. Inci'},
#       {'authorId': '14381946', 'name': 'Christine A Rüegg'},
#       {'authorId': '5225957', 'name': 'A. Saguner'}]}]},
#   {'authorId': '91077880',
#    'name': 'Thomas F. Müller Dr Med Vet',
#    'papers': [{'paperId': '37f227bd77eecf4b352d5d310e129ee9bc28c256',
#      'title': '6. Lyssavirus Infections',
#      'authors': [{'authorId': '91692738', 'name': 'Marc Artois Dmv'},
#       {'authorId': '91178200', 'name': 'Hervé Bourhy Dmv'},
#       {'authorId': '91077880', 'name': 'Thomas F. Müller Dr Med Vet'},
#       {'authorId': '91553078', 'name': 'Thomas Selhorst Dr'},
#       {'authorId': '91084602', 'name': 'G. Dr'}]}]}]}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_url = "https://api.semanticscholar.org/graph/v1/author/1741101?fields=aliases,name,papers.title,papers.abstract,papers.publicationDate,papers.externalIds,papers.s2FieldsOfStudy,papers.citationCount"

# %%
r = requests.get(my_url)
r
# Out:
# <Response [200]>

# %%
# 1
import requests

BASE_URL = 'https://api.semanticscholar.org/graph/'
VERSION = 'v1/'
RESOURCE = 'author/batch'

ids_json = {"ids" : ["2052431494","1741101"]}
params = {"fields": ["name,aliases,papers,papers.title,papers.abstract,papers.year,papers.externalIds,papers.s2FieldsOfStudy,papers.citationCount"]
          }

COMPLETE_URL = BASE_URL + VERSION + RESOURCE
response = requests.post(COMPLETE_URL,json=ids_json,params=params).json()

print(response)
# Out:
# [{'authorId': '2052431494', 'name': 'P. Howard', 'aliases': ['Philip . Howard', 'Philip Howard', 'Philip Eugene Howard'], 'papers': [{'paperId': 'a5631b6117b8ec6b2a56e6085e64f80776c7197b', 'externalIds': {'MAG': '1600322023', 'CorpusId': 153326170}, 'title': "Sunday-schools the world around; the official report of the World's fifth Sunday-school convention in Rome, May 18-23, 1907", 'abstract': None, 'year': 2010, 'citationCount': 1, 's2FieldsOfStudy': [{'category': 'History', 'source': 's2-fos-model'}]}, {'paperId': '542585c9d809017da154c5f3c7778fc45ca78ce2', 'externalIds': {'MAG': '2176545370', 'DOI': '10.1400/173374', 'CorpusId': 194111615}, 'title': 'The Villa dei Gordiani Project : The so-called Villa dei Gordiani at the 3rd mile of the Via Prenestina : Reassessment of a Roman and Medieval Site in the Suburbs of Rome', 'abstract': None, 'year': 2008, 'citationCount': 0, 's2FieldsOfStudy': [{'category': 'History', 'source': 's2-fos-model'}]}, {'paperId': '632a6e48b3cd2ad4b8fc8ea4198d54e091a20524', 'externalIds': {'MAG': '574112182', 'CorpusId': 60367996}, 'title': 'A Word in Time', 'abstract': 'A book about the English language in the 1990s and how it is changing day by day. The author aims to be both entertaining and scholarly. His previous books include "The State of the Language", "Winged Words" and "A Word in Your Ear".', 'year': 1991, 'citationCount': 13, 's2FieldsOfStudy': [{'category': 'Education', 'source': 's2-fos-model'}]}]}, {'authorId': '1741101', 'name': 'Oren Etzioni', 'aliases': ['O Et-zioni', 'Oren Etzioni'], 'papers': [{'paperId': 'cb92a7f9d9dbcf9145e32fdfa0e70e2a6b828eb1', 'externalIds': {'ArXiv': '2301.10140', 'DBLP': 'journals/corr/abs-2301-10140', 'DOI': '10.48550/arXiv.2301.10140', 'CorpusId': 256194545}, 'title': 'The Semantic Scholar Open Data Platform', 'abstract': 'The volume of scientific output is creating an urgent need for automated tools to help scientists keep up with developments in their field. Semantic Scholar (S2) is an open data platform and website aimed at accelerating science by helping scholars discover and understand scientific literature. We combine public and proprietary data sources using state-of-theart techniques for scholarly PDF content extraction and automatic knowledge graph construction to build the Semantic Scholar Academic Graph, the largest open scientific literature graph to-date, with 200M+ papers, 80M+ authors, 550M+ paper-authorship edges, and 2.4B+ citation edges. The graph includes advanced semantic features such as structurally parsed text, natural language summaries, and vector embeddings. In this paper, we describe the components of the S2 data processing pipeline and the associated APIs offered by the platform. We will update this living document to reflect changes as we add new data offerings and improve existing services.', 'year': 2023, 'citationCount': 0, 's2FieldsOfStudy': [{'category': 'Computer Science', 'source': 's2-fos-model'}]}, {'paperId': 'd1cf6bafac02ac65c7464bc7b168023584a688d7', 'externalIds': {'DBLP': 'journals/corr/abs-2205-02007', 'ArXiv': '2205.02007', 'DOI': '10.48550/arXiv.2205.02007', 'CorpusId': 248512482}, 'title': 'A Computational Inflection for Scientific Discovery', 'abstract': 'We stand at the foot of a significant inflection in the trajectory of scientific discovery. As society continues on its fast-paced digital transformation, so does humankind’s collective scientific knowledge and discourse. We now read and write papers in digitized form, and a great deal of the formal and informal processes of science are captured digitally—including papers, preprints and books, code and datasets, conference presentations, and interactions in social networks and collaboration and communication platforms. The transition has led to the creation and growth of a tremendous amount of information—much of which is available for public access—opening exciting opportunities for computational models and systems that analyze and harness it. In parallel, ...

# %%
# 2
import pandas as pd

# %% [markdown]
# ## Week 3 (Data Visualization)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Vi vælger mean & Standard deviatiob for vores normal fordeling
mu = 0
sigma = 4
# laver en random sample af 10.000 data points for normal fordeling
X = np.random.standard_normal(size=10000) * sigma + mu
# Laver histogram
plt.hist(X, bins=50)

plt.title("Histogram of Gaussian Data")
plt.xlabel("Data Value")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Find cumulative sum
#Cumulative sums, or running totals, are used to display the total sum of data as it grows with time
cumulative_sum = np.cumsum(X)


sequence = np.arange(1, len(X)+1)
cumulative_average = cumulative_sum / sequence

#Finder cumulative standard error
cumulative_std_error = np.zeros_like(X)
for i in range(1, len(X) + 1):
    subsequence = X[:i]
    sigma = np.std(subsequence, ddof=1)
    n = len(subsequence)
    std_error = sigma / np.sqrt(n)
    cumulative_std_error[i-1] = std_error

#Finder mean and median
distribution_mean = np.mean(X)
distribution_median = np.median(X)

#Lav en figur med "cumulative average" med error bar og mean
fig, ax = plt.subplots()
#errorbar med "width equal to the standard error of the mean"
ax.errorbar(np.arange(1, len(X) + 1), cumulative_average, yerr=cumulative_std_error, fmt='-', label='Cumulative Average', color = "k")
#vandret linje
ax.axhline(distribution_mean, color='r', linestyle='--', label='Distribution Mean')

ax.set_title('Cumulative Average with Error Bars')
ax.set_xlabel('Sample Size')
ax.set_ylabel('Average')
ax.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Find median 
cumulative_median = np.zeros_like(X)
for i in range(len(X)):
    subsequence = X[:i+1]
    cumulative_median[i] = np.median(subsequence)
#Lav figur
fig, ax = plt.subplots()
#Cumulative median som linje plot
ax.plot(np.arange(len(X)) + 1, cumulative_median)

#vandret linje
ax.axhline(distribution_median, linestyle='--', color='red')

ax.set_xlabel('Sample Size')
ax.set_ylabel('Cumulative Median')
plt.show()
