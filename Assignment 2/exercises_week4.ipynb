# %%
import pandas as pd
import numpy as np
import ast
author_data = pd.read_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\author_df.csv')
paper_data = pd.read_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\paper_df.csv')

author_id_list_x = [119457888,50013417]

def TopField(author_data,author_id_list):

    return list(author_data[author_data['authorId'].isin(author_id_list)].get('field'))

field_data = []
for (count, paper_id) in enumerate(paper_data.get('authorIds')):
    x = ast.literal_eval(paper_id)
    x = [int(i) for i in x]
    field_data_x = TopField(author_data, x)
    if count % 10000 == 0:
        print(count)
    field_data.append(field_data_x)
    

field_data_pd = pd.DataFrame({'author_field': field_data})

paper_data['author_field'] = field_data_pd

#This takes a while to run, so better to save as new csv file
#paper_data.to_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\paper.....csv')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000

# %%
import pandas as pd
import numpy as np
import ast
# load paper data with author field
paper_data = pd.read_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\paper_w_author_field_df.csv')

# %%
css_df = pd.DataFrame(columns=['Unnamed: 0', 'paperId', 'title', 'year', 'externalId.DOI',
       'citationCount', 'authorIds', 'fields', 'author_field'])

# %%
#css_data is paper data 
social_science_fields = ['Political Science', 'Sociology', 'Economics']
quantitative_fields = ['Mathematics','Physics','Computer Science']


for count in range(len(paper_data['author_field'])):
    
    #print('count',count)
    row = paper_data.iloc[count]

    auth_field = ast.literal_eval(row.author_field.replace('nan,', '').replace('nan]', ']').replace('[nan', '[').replace('[nan]', '[]'))

    field = ast.literal_eval(row.author_field.replace('nan,', '').replace('nan]', ']').replace('[nan', '[').replace('[nan]', '[]'))
    
    id_DOI = "skip" if pd.isna(row['externalId.DOI']) else ast.literal_eval(row['externalId.DOI'])
    
    if (auth_field == []) or (field == []) or (id_DOI == "skip"):
        continue
    
    
    criterias =     ([x for x in field if x in social_science_fields]) and \
                    (([x for x in field if x in quantitative_fields]) or ([x for x in auth_field if x in quantitative_fields])) and \
                    (row.year >= 2009) and \
                    (len(ast.literal_eval(row['authorIds'])) <= 10) and \
                    ('Biology' not in field) and \
                    (id_DOI.get('DOI') != None)
    
    if criterias:
        #add row if criteria is met:
        css_df = pd.concat([css_df, pd.DataFrame([row])], axis=0, ignore_index = True)
        print(f'appended count {count} to dataframe')
# Out:
# appended count 263 to dataframe
# appended count 1672 to dataframe
# appended count 1673 to dataframe
# appended count 1676 to dataframe
# appended count 3607 to dataframe
# appended count 3608 to dataframe
# appended count 3614 to dataframe
# appended count 3615 to dataframe
# appended count 3616 to dataframe
# appended count 3619 to dataframe
# appended count 3620 to dataframe
# appended count 3621 to dataframe
# appended count 3636 to dataframe
# appended count 4984 to dataframe
# appended count 4985 to dataframe
# appended count 5032 to dataframe
# appended count 5548 to dataframe
# appended count 5561 to dataframe
# appended count 5562 to dataframe
# appended count 5570 to dataframe
# appended count 6491 to dataframe
# appended count 6637 to dataframe
# appended count 6639 to dataframe
# appended count 6641 to dataframe
# appended count 6643 to dataframe
# appended count 6644 to dataframe
# appended count 6648 to dataframe
# appended count 6649 to dataframe
# appended count 6650 to dataframe
# appended count 6652 to dataframe
# appended count 6659 to dataframe
# appended count 6663 to dataframe
# appended count 6666 to dataframe
# appended count 6678 to dataframe
# appended count 6681 to dataframe
# appended count 6696 to dataframe
# appended count 6705 to dataframe
# appended count 6710 to dataframe
# appended count 6727 to dataframe
# appended count 6732 to dataframe
# appended count 6752 to dataframe
# appended count 6753 to dataframe
# appended count 6904 to dataframe
# appended count 6908 to dataframe
# appended count 6915 to dataframe
# appended count 6916 to dataframe
# appended count 6919 to dataframe
# appended count 6925 to dataframe
# appended count 6927 to dataframe
# appended count 6930 to dataframe
# appended count 6936 to dataframe
# appended count 9504 to dataframe
# appended count 9821 to dataframe
# appended count 10399 to dataframe
# appended count 10400 to dataframe
# appended count 10401 to dataframe
# appended count 10404 to dataframe
# appended count 10405 to dataframe
# appended count 10460 to dataframe
# appended count 10483 to dataframe
# appended count 10837 to dataframe
# appended count 12135 to dataframe
# appended count 13358 to dataframe
# appended count 13377 to dataframe
# appended count 13397 to dataframe
# appended count 13404 to dataframe
# appended count 13416 to dataframe
# appended count 13861 to dataframe
# appended count 13862 to dataframe
# appended count 13865 to dataframe
# appended count 13867 to dataframe
# appended count 13868 to dataframe
# appended count 13874 to dataframe
# appended count 13902 to dataframe
# appended count 13992 to dataframe
# appended count 13993 to dataframe
# appended count 13994 to dataframe
# appended count 13995 to dataframe
# appended count 13998 to dataframe
# appended count 14106 to dataframe
# appended count 14303 to dataframe
# appended count 15027 to dataframe
# appended count 15030 to dataframe
# appended count 15285 to dataframe
# appended count 15464 to dataframe
# appended count 16429 to dataframe
# appended count 16440 to dataframe
# appended count 16443 to dataframe
# appended count 16444 to dataframe
# appended count 16445 to dataframe
# appended count 16447 to dataframe
# appended count 16449 to dataframe
# appended count 16450 to dataframe
# appended count 16451 to dataframe
# appended count 16620 to dataframe
# appended count 16663 to dataframe
# appended count 18461 to dataframe
# appended count 20349 to dataframe
# appended count 20352 to dataframe
# appended count 22977 to dataframe
# appended count 22984 to dataframe
# appended count 22985 to dataframe
# appended count 22988 to dataframe
# appended count 23095 to dataframe
# appended count 23154 to dataframe
# appended count 23161 to dataframe
# appended count 23435 to dataframe
# appended count 25456 to dataframe
# appended count 27741 to dataframe
# appended count 28820 to dataframe
# appended count 30108 to dataframe
# appended count 30114 to dataframe
# appended count 30129 to dataframe
# appended count 30182 to dataframe
# appended count 31050 to dataframe
# appended count 31386 to dataframe
# appended count 31971 to dataframe
# appended count 31972 to dataframe
# appended count 31973 to dataframe
# appended count 31974 to dataframe
# appended count 31975 to dataframe
# appended count 31976 to dataframe
# appended count 31978 to dataframe
# appended count 31979 to dataframe
# appended count 31980 to dataframe
# appended count 31981 to dataframe
# appended count 31982 to dataframe
# appended count 31983 to dataframe
# appended count 31984 to dataframe
# appended count 31985 to dataframe
# appended count 31986 to dataframe
# appended count 31987 to dataframe
# appended count 31988 to dataframe
# appended count 31989 to dataframe
# appended count 31990 to dataframe
# appended count 31991 to dataframe
# appended count 31992 to dataframe
# appended count 31993 to dataframe
# appended count 31994 to dataframe
# appended count 31995 to dataframe
# appended count 31996 to dataframe
# appended count 31997 to dataframe
# appended count 31998 to dataframe
# appended count 31999 to dataframe
# appended count 32001 to dataframe
# appended count 32002 to dataframe
# appended count 32003 to dataframe
# appended count 32004 to dataframe
# appended count 32005 to dataframe
# appended count 32006 to dataframe
# appended count 32007 to dataframe
# appended count 32008 to dataframe
# appended count 32009 to dataframe
# appended count 32010 to dataframe
# appended count 32011 to dataframe
# appended count 32012 to dataframe
# appended count 32013 to dataframe
# appended count 32014 to dataframe
# appended count 32015 to dataframe
# appended count 32016 to dataframe
# appended count 32017 to dataframe
# appended count 32018 to dataframe
# appended count 32019 to dataframe
# appended count 32020 to dataframe
# appended count 32021 to dataframe
# appended count 32022 to dataframe
# appended count 32023 to dataframe
# appended count 32024 to dataframe
# appended count 32025 to dataframe
# appended count 32026 to dataframe
# appended count 32027 to dataframe
# appended count 32028 to dataframe
# appended count 32029 to dataframe
# appended count 32030 to dataframe
# appended count 32031 to dataframe
# appended count 32032 to dataframe
# appended count 32033 to dataframe
# appended count 32034 to dataframe
# appended count 32035 to dataframe
# appended count 32036 to dataframe
# appended count 32037 to dataframe
# appended count 32038 to dataframe
# appended count 32039 to dataframe
# appended count 32041 to dataframe
# appended count 32042 to dataframe
# appended count 32043 to dataframe
# appended count 32044 to dataframe
# appended count 32045 to dataframe
# appended count 32046 to dataframe
# appended count 32047 to dataframe
# appended count 32051 to dataframe
# appended count 32052 to dataframe
# appended count 32053 to dataframe
# appended count 32055 to dataframe
# appended count 32056 to dataframe
# appended count 32058 to dataframe
# appended count 32062 to dataframe
# appended count 32064 to dataframe
# appended count 32069 to dataframe
# appended count 32070 to dataframe
# appended count 32071 to dataframe
# appended count 32072 to dataframe
# appended count 32074 to dataframe
# appended count 32079 to dataframe
# appended count 32738 to dataframe
# appended count 32743 to dataframe
# appended count 32745 to dataframe
# appended count 32746 to dataframe
# appended count 32747 to dataframe
# appended count 32748 to dataframe
# appended count 32749 to dataframe
# appended count 32751 to dataframe
# appended count 32753 to dataframe
# appended count 32754 to dataframe
# appended count 32755 to dataframe
# appended count 32756 to dataframe
# appended count 32757 to dataframe
# appended count 32758 to dataframe
# appended count 32760 to dataframe
# appended count 32761 to dataframe
# appended count 32762 to dataframe
# appended count 32763 to dataframe
# appended count 32764 to dataframe
# appended count 32769 to dataframe
# appended count 32770 to dataframe
# appended count 32771 to dataframe
# appended count 32772 to dataframe
# appended count 32780 to dataframe
# appended count 33058 to dataframe
# appended count 33448 to dataframe
# appended count 33466 to dataframe
# appended count 33468 to dataframe
# appended count 36449 to dataframe
# appended count 36773 to dataframe
# appended count 36781 to dataframe
# appended count 36899 to dataframe
# appended count 36903 to dataframe
# appended count 36914 to dataframe
# appended count 36915 to dataframe
# appended count 36916 to dataframe
# appended count 37219 to dataframe
# appended count 37512 to dataframe
# appended count 37513 to dataframe
# appended count 37516 to dataframe
# appended count 37520 to dataframe
# appended count 37521 to dataframe
# appended count 37523 to dataframe
# appended count 37623 to dataframe
# appended count 37632 to dataframe
# appended count 41296 to dataframe
# appended count 41498 to dataframe
# appended count 41512 to dataframe
# appended count 41655 to dataframe
# appended count 41656 to dataframe
# appended count 43936 to dataframe
# appended count 43937 to dataframe
# appended count 44197 to dataframe
# appended count 45153 to dataframe
# appended count 45156 to dataframe
# appended count 45161 to dataframe
# appended count 45190 to dataframe
# appended count 46580 to dataframe
# appended count 46581 to dataframe
# appended count 47207 to dataframe
# appended count 47347 to dataframe
# appended count 47571 to dataframe
# appended count 47576 to dataframe
# appended count 47577 to dataframe
# appended count 47579 to dataframe
# appended count 47580 to dataframe
# appended count 47653 to dataframe
# appended count 48356 to dataframe
# appended count 48651 to dataframe
# appended count 48883 to dataframe
# appended count 48896 to dataframe
# appended count 48899 to dataframe
# appended count 48915 to dataframe
# appended count 48923 to dataframe
# appended count 48926 to dataframe
# appended count 48929 to dataframe
# appended count 48931 to dataframe
# appended count 48932 to dataframe
# appended count 48938 to dataframe
# appended count 48941 to dataframe
# appended count 48942 to dataframe
# appended count 48944 to dataframe
# appended count 48949 to dataframe
# appended count 48951 to dataframe
# appended count 48963 to dataframe
# appended count 48965 to dataframe
# appended count 48969 to dataframe
# appended count 48977 to dataframe
# appended count 49874 to dataframe
# appended count 49876 to dataframe
# appended count 49880 to dataframe
# appended count 49881 to dataframe
# appended count 49882 to dataframe
# appended count 49885 to dataframe
# appended count 49901 to dataframe
# appended count 52249 to dataframe
# appended count 52256 to dataframe
# appended count 52257 to dataframe
# appended count 52259 to dataframe
# appended count 52261 to dataframe
# appended count 52262 to dataframe
# appended count 52263 to dataframe
# appended count 52264 to dataframe
# appended count 52266 to dataframe
# appended count 52267 to dataframe
# appended count 52270 to dataframe
# appended count 52271 to dataframe
# appended count 52272 to dataframe
# appended count 52273 to dataframe
# appended count 52274 to dataframe
# appended count 52275 to dataframe
# appended count 52278 to dataframe
# appended count 52299 to dataframe
# appended count 52306 to dataframe
# appended count 52411 to dataframe
# appended count 52429 to dataframe
# appended count 53780 to dataframe
# appended count 53785 to dataframe
# appended count 54192 to dataframe
# appended count 54195 to dataframe
# appended count 54196 to dataframe
# appended count 54198 to dataframe
# appended count 55045 to dataframe
# appended count 55049 to dataframe
# appended count 55054 to dataframe
# appended count 55055 to dataframe
# appended count 55056 to dataframe
# appended count 55060 to dataframe
# appended count 55061 to dataframe
# appended count 55062 to dataframe
# appended count 55067 to dataframe
# appended count 55068 to dataframe
# appended count 56371 to dataframe
# appended count 56390 to dataframe
# appended count 58270 to dataframe
# appended count 58311 to dataframe
# appended count 60515 to dataframe
# appended count 60530 to dataframe
# appended count 60891 to dataframe
# appended count 60892 to dataframe
# appended count 60893 to dataframe
# appended count 60894 to dataframe
# appended count 60896 to dataframe
# appended count 60898 to dataframe
# appended count 60901 to dataframe
# appended count 60902 to dataframe
# appended count 60904 to dataframe
# appended count 60906 to dataframe
# appended count 60907 to dataframe
# appended count 60909 to dataframe
# appended count 60914 to dataframe
# appended count 61346 to dataframe
# appended count 61369 to dataframe
# appended count 62158 to dataframe
# appended count 62873 to dataframe
# appended count 62874 to dataframe
# appended count 62876 to dataframe
# appended count 62879 to dataframe
# appended count 62884 to dataframe
# appended count 64013 to dataframe
# appended count 64023 to dataframe
# appended count 64903 to dataframe
# appended count 64985 to dataframe
# appended count 65004 to dataframe
# appended count 65010 to dataframe
# appended count 65015 to dataframe
# appended count 65031 to dataframe
# appended count 65255 to dataframe
# appended count 65259 to dataframe
# appended count 65261 to dataframe
# appended count 65262 to dataframe
# appended count 65265 to dataframe
# appended count 65266 to dataframe
# appended count 65316 to dataframe
# appended count 65323 to dataframe
# appended count 65326 to dataframe
# appended count 65332 to dataframe
# appended count 65338 to dataframe
# appended count 65345 to dataframe
# appended count 65360 to dataframe
# appended count 65371 to dataframe
# appended count 65378 to dataframe
# appended count 65380 to dataframe
# appended count 65381 to dataframe
# appended count 65382 to dataframe
# appended count 65386 to dataframe
# appended count 65970 to dataframe
# appended count 65979 to dataframe
# appended count 65980 to dataframe
# appended count 65986 to dataframe
# appended count 65989 to dataframe
# appended count 65990 to dataframe
# appended count 65994 to dataframe
# appended count 65997 to dataframe
# appended count 65999 to dataframe
# appended count 66003 to dataframe
# appended count 66004 to dataframe
# appended count 66006 to dataframe
# appended count 66008 to dataframe
# appended count 66009 to dataframe
# appended count 66018 to dataframe
# appended count 66026 to dataframe
# appended count 66035 to dataframe
# appended count 66038 to dataframe
# appended count 67042 to dataframe
# appended count 67614 to dataframe
# appended count 68120 to dataframe
# appended count 68139 to dataframe
# appended count 68147 to dataframe
# appended count 68154 to dataframe
# appended count 68163 to dataframe
# appended count 69242 to dataframe
# appended count 69539 to dataframe
# appended count 71609 to dataframe
# appended count 71610 to dataframe
# appended count 71611 to dataframe
# appended count 71612 to dataframe
# appended count 71613 to dataframe
# appended count 71614 to dataframe
# appended count 71617 to dataframe
# appended count 72221 to dataframe
# appended count 72226 to dataframe
# appended count 72229 to dataframe
# appended count 72478 to dataframe
# appended count 73295 to dataframe
# appended count 74850 to dataframe
# appended count 75788 to dataframe
# appended count 77234 to dataframe
# appended count 77688 to dataframe
# appended count 78511 to dataframe
# appended count 79305 to dataframe
# appended count 79307 to dataframe
# appended count 79312 to dataframe
# appended count 79314 to dataframe
# appended count 79377 to dataframe
# appended count 80065 to dataframe
# appended count 80085 to dataframe
# appended count 80398 to dataframe
# appended count 80401 to dataframe
# appended count 80403 to dataframe
# appended count 80405 to dataframe
# appended count 80418 to dataframe
# appended count 81996 to dataframe
# appended count 82001 to dataframe
# appended count 82731 to dataframe
# appended count 83196 to dataframe
# appended count 83219 to dataframe
# appended count 83221 to dataframe
# appended count 83225 to dataframe
# appended count 83548 to dataframe
# appended count 83549 to dataframe
# appended count 83557 to dataframe
# appended count 86329 to dataframe
# appended count 87485 to dataframe
# appended count 87487 to dataframe
# appended count 87490 to dataframe
# appended count 87509 to dataframe
# appended count 87511 to dataframe
# appended count 87514 to dataframe
# appended count 87516 to dataframe
# appended count 87517 to dataframe
# appended count 87519 to dataframe
# appended count 87520 to dataframe
# appended count 87523 to dataframe
# appended count 87526 to dataframe
# appended count 87540 to dataframe
# appended count 87549 to dataframe
# appended count 87553 to dataframe
# appended count 87554 to dataframe
# appended count 87558 to dataframe
# appended count 87562 to dataframe
# appended count 87571 to dataframe
# appended count 87573 to dataframe
# appended count 87705 to dataframe
# appended count 87709 to dataframe
# appended count 87917 to dataframe
# appended count 87919 to dataframe
# appended count 87922 to dataframe
# appended count 89685 to dataframe
# appended count 89700 to dataframe
# appended count 89703 to dataframe
# appended count 89706 to dataframe
# appended count 93280 to dataframe
# appended count 93283 to dataframe
# appended count 93423 to dataframe
# appended count 93660 to dataframe
# appended count 93676 to dataframe
# appended count 93693 to dataframe
# appended count 93722 to dataframe
# appended count 93725 to dataframe
# appended count 93731 to dataframe
# appended count 93732 to dataframe
# appended count 93742 to dataframe
# appended count 93750 to dataframe
# appended count 93755 to dataframe
# appended count 93767 to dataframe
# appended count 93780 to dataframe
# appended count 93783 to dataframe
# appended count 93790 to dataframe
# appended count 93795 to dataframe
# appended count 93796 to dataframe
# appended count 93798 to dataframe
# appended count 93802 to dataframe
# appended count 93812 to dataframe
# appended count 93818 to dataframe
# appended count 93821 to dataframe
# appended count 93822 to dataframe
# appended count 93842 to dataframe
# appended count 93864 to dataframe
# appended count 93879 to dataframe
# appended count 95419 to dataframe
# appended count 97698 to dataframe
# appended count 98278 to dataframe
# appended count 98336 to dataframe
# appended count 98649 to dataframe
# appended count 98650 to dataframe
# appended count 98651 to dataframe
# appended count 98653 to dataframe
# appended count 98654 to dataframe
# appended count 99023 to dataframe
# appended count 99024 to dataframe
# appended count 99027 to dataframe
# appended count 99063 to dataframe
# appended count 99124 to dataframe
# appended count 99130 to dataframe
# appended count 99144 to dataframe
# appended count 99156 to dataframe
# appended count 99161 to dataframe
# appended count 99172 to dataframe
# appended count 99185 to dataframe
# appended count 99203 to dataframe
# appended count 99227 to dataframe
# appended count 99228 to dataframe
# appended count 99376 to dataframe
# appended count 100556 to dataframe
# appended count 101903 to dataframe
# appended count 104407 to dataframe
# appended count 104494 to dataframe
# appended count 105990 to dataframe
# appended count 106880 to dataframe
# appended count 108104 to dataframe
# appended count 108111 to dataframe
# appended count 108550 to dataframe
# appended count 108556 to dataframe
# appended count 108557 to dataframe
# appended count 108558 to dataframe
# appended count 108561 to dataframe
# appended count 108562 to dataframe
# appended count 108566 to dataframe
# appended count 108567 to dataframe
# appended count 108568 to dataframe
# appended count 108569 to dataframe
# appended count 108570 to dataframe
# appended count 108571 to dataframe
# appended count 108572 to dataframe
# appended count 108573 to dataframe
# appended count 108575 to dataframe
# appended count 108576 to dataframe
# appended count 108577 to dataframe
# appended count 108578 to dataframe
# appended count 108580 to dataframe
# appended count 108581 to dataframe
# appended count 108582 to dataframe
# appended count 108583 to dataframe
# appended count 108584 to dataframe
# appended count 108586 to dataframe
# appended count 108587 to dataframe
# appended count 108588 to dataframe
# appended count 108590 to dataframe
# appended count 108595 to dataframe
# appended count 108599 to dataframe
# appended count 108601 to dataframe
# appended count 108603 to dataframe
# appended count 108606 to dataframe
# appended count 108748 to dataframe
# appended count 108755 to dataframe
# appended count 110727 to dataframe
# appended count 110868 to dataframe
# appended count 111152 to dataframe
# appended count 112841 to dataframe
# appended count 112847 to dataframe
# appended count 113962 to dataframe
# appended count 114937 to dataframe
# appended count 114938 to dataframe
# appended count 115888 to dataframe
# appended count 115891 to dataframe
# appended count 116448 to dataframe
# appended count 116521 to dataframe
# appended count 118802 to dataframe
# appended count 118805 to dataframe
# appended count 118806 to dataframe
# appended count 120023 to dataframe
# appended count 121554 to dataframe
# appended count 123513 to dataframe
# appended count 123514 to dataframe
# appended count 123520 to dataframe
# appended count 123522 to dataframe
# appended count 123534 to dataframe
# appended count 123543 to dataframe
# appended count 123817 to dataframe
# appended count 123825 to dataframe
# appended count 123839 to dataframe
# appended count 123868 to dataframe
# appended count 123895 to dataframe
# appended count 125206 to dataframe
# appended count 125212 to dataframe
# appended count 126518 to dataframe
# appended count 126522 to dataframe
# appended count 126523 to dataframe
# appended count 128367 to dataframe
# appended count 129604 to dataframe
# appended count 129616 to dataframe
# appended count 129622 to dataframe
# appended count 133128 to dataframe
# appended count 133723 to dataframe
# appended count 134195 to dataframe
# appended count 134196 to dataframe
# appended count 134197 to dataframe
# appended count 134199 to dataframe
# appended count 134990 to dataframe
# appended count 134991 to dataframe
# appended count 134993 to dataframe
# appended count 135001 to dataframe
# appended count 135014 to dataframe
# appended count 135019 to dataframe
# appended count 135029 to dataframe
# appended count 135032 to dataframe
# appended count 135033 to dataframe
# appended count 135034 to dataframe
# appended count 135035 to dataframe
# appended count 135038 to dataframe
# appended count 135040 to dataframe
# appended count 136876 to dataframe
# appended count 136878 to dataframe
# appended count 136886 to dataframe
# appended count 136887 to dataframe
# appended count 136888 to dataframe
# appended count 136889 to dataframe
# appended count 136890 to dataframe
# appended count 136891 to dataframe
# appended count 136892 to dataframe
# appended count 136893 to dataframe
# appended count 136894 to dataframe
# appended count 136895 to dataframe
# appended count 136896 to dataframe
# appended count 136897 to dataframe
# appended count 136900 to dataframe
# appended count 136902 to dataframe
# appended count 136903 to dataframe
# appended count 136904 to dataframe
# appended count 136905 to dataframe
# appended count 136906 to dataframe
# appended count 136907 to dataframe
# appended count 136908 to dataframe
# appended count 136914 to dataframe
# appended count 136915 to dataframe
# appended count 136916 to dataframe
# appended count 136917 to dataframe
# appended count 136918 to dataframe
# appended count 136919 to dataframe
# appended count 136920 to dataframe
# appended count 136921 to dataframe
# appended count 136922 to dataframe
# appended count 136923 to dataframe
# appended count 136924 to dataframe
# appended count 136925 to dataframe
# appended count 136926 to dataframe
# appended count 136927 to dataframe
# appended count 138282 to dataframe
# appended count 138286 to dataframe
# appended count 138316 to dataframe
# appended count 138490 to dataframe
# appended count 138492 to dataframe
# appended count 138495 to dataframe
# appended count 138499 to dataframe
# appended count 138598 to dataframe
# appended count 139444 to dataframe
# appended count 144760 to dataframe
# appended count 145356 to dataframe
# appended count 145364 to dataframe
# appended count 145366 to dataframe
# appended count 145383 to dataframe
# appended count 145387 to dataframe
# appended count 145398 to dataframe
# appended count 145401 to dataframe
# appended count 145403 to dataframe
# appended count 145425 to dataframe
# appended count 145428 to dataframe
# appended count 145429 to dataframe
# appended count 145431 to dataframe
# appended count 145432 to dataframe
# appended count 145433 to dataframe
# appended count 145436 to dataframe
# appended count 145446 to dataframe
# appended count 145560 to dataframe
# appended count 145580 to dataframe
# appended count 145582 to dataframe
# appended count 145583 to dataframe
# appended count 145586 to dataframe
# appended count 145593 to dataframe
# appended count 145597 to dataframe
# appended count 145599 to dataframe
# appended count 146643 to dataframe
# appended count 146985 to dataframe
# appended count 146988 to dataframe
# appended count 146995 to dataframe
# appended count 146999 to dataframe
# appended count 147384 to dataframe
# appended count 147446 to dataframe
# appended count 147461 to dataframe
# appended count 149841 to dataframe
# appended count 150657 to dataframe
# appended count 150659 to dataframe
# appended count 150667 to dataframe
# appended count 150669 to dataframe
# appended count 151125 to dataframe
# appended count 151168 to dataframe
# appended count 151194 to dataframe
# appended count 151237 to dataframe
# appended count 151238 to dataframe
# appended count 151255 to dataframe
# appended count 151265 to dataframe
# appended count 151268 to dataframe
# appended count 151276 to dataframe
# appended count 151317 to dataframe
# appended count 151331 to dataframe
# appended count 151336 to dataframe
# appended count 151381 to dataframe
# appended count 151443 to dataframe
# appended count 151482 to dataframe
# appended count 151524 to dataframe
# appended count 151546 to dataframe
# appended count 151569 to dataframe
# appended count 151868 to dataframe
# appended count 154227 to dataframe
# appended count 154228 to dataframe
# appended count 154234 to dataframe
# appended count 154238 to dataframe
# appended count 154244 to dataframe
# appended count 154255 to dataframe
# appended count 154256 to dataframe
# appended count 156891 to dataframe
# appended count 157845 to dataframe
# appended count 157978 to dataframe
# appended count 157990 to dataframe
# appended count 157994 to dataframe
# appended count 159759 to dataframe
# appended count 160255 to dataframe
# appended count 160267 to dataframe
# appended count 160357 to dataframe
# appended count 162226 to dataframe
# appended count 162502 to dataframe
# appended count 165237 to dataframe
# appended count 166776 to dataframe
# appended count 166777 to dataframe
# appended count 167262 to dataframe
# appended count 167265 to dataframe
# appended count 170499 to dataframe
# appended count 172897 to dataframe
# appended count 172907 to dataframe
# appended count 174520 to dataframe
# appended count 176346 to dataframe
# appended count 176567 to dataframe
# appended count 176579 to dataframe
# appended count 178441 to dataframe
# appended count 178456 to dataframe
# appended count 178475 to dataframe
# appended count 180529 to dataframe
# appended count 180540 to dataframe
# appended count 181026 to dataframe
# appended count 182299 to dataframe
# appended count 182315 to dataframe
# appended count 182320 to dataframe
# appended count 182329 to dataframe
# appended count 182332 to dataframe
# appended count 182345 to dataframe
# appended count 182346 to dataframe
# appended count 182354 to dataframe
# appended count 182363 to dataframe
# appended count 182436 to dataframe
# appended count 182935 to dataframe
# appended count 182936 to dataframe
# appended count 182984 to dataframe
# appended count 183423 to dataframe
# appended count 183446 to dataframe
# appended count 184393 to dataframe
# appended count 188132 to dataframe
# appended count 188138 to dataframe
# appended count 188139 to dataframe
# appended count 188140 to dataframe
# appended count 188141 to dataframe
# appended count 188144 to dataframe
# appended count 188149 to dataframe
# appended count 192610 to dataframe
# appended count 192618 to dataframe
# appended count 192990 to dataframe
# appended count 195472 to dataframe
# appended count 195480 to dataframe
# appended count 197116 to dataframe
# appended count 197117 to dataframe
# appended count 200443 to dataframe
# appended count 200450 to dataframe
# appended count 200456 to dataframe
# appended count 200533 to dataframe
# appended count 207619 to dataframe
# appended count 208545 to dataframe
# appended count 208844 to dataframe
# appended count 208851 to dataframe
# appended count 211412 to dataframe
# appended count 211429 to dataframe
# appended count 212489 to dataframe
# appended count 213020 to dataframe
# appended count 214305 to dataframe
# appended count 214311 to dataframe
# appended count 217882 to dataframe
# appended count 217891 to dataframe
# appended count 217917 to dataframe
# appended count 217931 to dataframe
# appended count 217935 to dataframe
# appended count 217939 to dataframe
# appended count 217949 to dataframe
# appended count 219048 to dataframe
# appended count 220513 to dataframe
# appended count 220515 to dataframe
# appended count 220529 to dataframe
# appended count 220530 to dataframe
# appended count 220958 to dataframe
# appended count 221622 to dataframe
# appended count 221632 to dataframe
# appended count 221635 to dataframe
# appended count 221661 to dataframe
# appended count 221677 to dataframe
# appended count 221687 to dataframe
# appended count 225046 to dataframe
# appended count 225779 to dataframe
# appended count 228411 to dataframe
# appended count 228420 to dataframe
# appended count 228423 to dataframe
# appended count 233158 to dataframe
# appended count 235373 to dataframe
# appended count 235540 to dataframe
# appended count 235821 to dataframe
# appended count 235830 to dataframe
# appended count 236954 to dataframe
# appended count 236957 to dataframe
# appended count 236958 to dataframe
# appended count 236959 to dataframe
# appended count 237621 to dataframe
# appended count 237644 to dataframe
# appended count 237652 to dataframe
# appended count 237670 to dataframe
# appended count 237679 to dataframe
# appended count 237685 to dataframe
# appended count 239522 to dataframe
# appended count 239953 to dataframe
# appended count 240740 to dataframe
# appended count 240741 to dataframe
# appended count 240742 to dataframe
# appended count 240743 to dataframe
# appended count 240745 to dataframe
# appended count 240754 to dataframe
# appended count 240814 to dataframe
# appended count 240816 to dataframe
# appended count 240817 to dataframe
# appended count 241484 to dataframe
# appended count 243510 to dataframe
# appended count 243511 to dataframe
# appended count 245372 to dataframe
# appended count 245374 to dataframe
# appended count 245378 to dataframe
# appended count 245379 to dataframe
# appended count 245381 to dataframe
# appended count 248131 to dataframe
# appended count 248132 to dataframe
# appended count 248186 to dataframe
# appended count 248190 to dataframe
# appended count 248934 to dataframe
# appended count 248935 to dataframe
# appended count 249252 to dataframe
# appended count 249253 to dataframe
# appended count 250056 to dataframe
# appended count 250063 to dataframe
# appended count 250067 to dataframe
# appended count 250068 to dataframe
# appended count 250071 to dataframe
# appended count 250083 to dataframe
# appended count 250085 to dataframe
# appended count 250088 to dataframe
# appended count 250095 to dataframe
# appended count 250480 to dataframe
# appended count 250481 to dataframe
# appended count 250482 to dataframe
# appended count 250483 to dataframe
# appended count 250485 to dataframe
# appended count 250505 to dataframe
# appended count 250916 to dataframe
# appended count 251004 to dataframe
# appended count 252144 to dataframe
# appended count 252147 to dataframe
# appended count 252195 to dataframe
# appended count 252217 to dataframe
# appended count 252237 to dataframe
# appended count 252253 to dataframe
# appended count 252254 to dataframe
# appended count 252320 to dataframe
# appended count 254059 to dataframe
# appended count 254060 to dataframe
# appended count 254062 to dataframe
# appended count 254069 to dataframe
# appended count 254070 to dataframe
# appended count 254072 to dataframe
# appended count 254073 to dataframe
# appended count 254074 to dataframe
# appended count 254075 to dataframe
# appended count 254076 to dataframe
# appended count 254078 to dataframe
# appended count 254082 to dataframe
# appended count 254745 to dataframe
# appended count 254852 to dataframe
# appended count 254858 to dataframe
# appended count 254859 to dataframe
# appended count 255815 to dataframe
# appended count 255829 to dataframe
# appended count 256747 to dataframe
# appended count 256750 to dataframe
# appended count 256755 to dataframe
# appended count 256779 to dataframe
# appended count 258517 to dataframe
# appended count 258520 to dataframe
# appended count 258521 to dataframe
# appended count 258523 to dataframe
# appended count 258526 to dataframe
# appended count 258528 to dataframe
# appended count 258934 to dataframe
# appended count 261067 to dataframe
# appended count 263425 to dataframe
# appended count 263700 to dataframe
# appended count 263706 to dataframe
# appended count 263710 to dataframe
# appended count 263713 to dataframe
# appended count 263738 to dataframe
# appended count 263748 to dataframe
# appended count 265505 to dataframe
# appended count 265510 to dataframe
# appended count 265513 to dataframe
# appended count 266790 to dataframe
# appended count 267269 to dataframe
# appended count 267277 to dataframe
# appended count 267288 to dataframe
# appended count 267299 to dataframe
# appended count 267327 to dataframe
# appended count 267462 to dataframe
# appended count 267487 to dataframe
# appended count 270382 to dataframe
# appended count 270652 to dataframe
# appended count 271840 to dataframe
# appended count 272178 to dataframe
# appended count 272180 to dataframe
# appended count 272182 to dataframe
# appended count 272190 to dataframe
# appended count 272202 to dataframe
# appended count 272499 to dataframe
# appended count 272537 to dataframe
# appended count 272695 to dataframe
# appended count 273120 to dataframe
# appended count 273121 to dataframe
# appended count 273122 to dataframe
# appended count 273124 to dataframe
# appended count 273125 to dataframe
# appended count 273215 to dataframe
# appended count 273216 to dataframe
# appended count 273217 to dataframe
# appended count 273238 to dataframe
# appended count 273239 to dataframe
# appended count 276391 to dataframe
# appended count 276400 to dataframe
# appended count 276401 to dataframe
# appended count 276402 to dataframe
# appended count 276410 to dataframe
# appended count 276680 to dataframe
# appended count 276759 to dataframe
# appended count 276770 to dataframe
# appended count 276772 to dataframe
# appended count 276874 to dataframe
# appended count 276875 to dataframe
# appended count 276880 to dataframe
# appended count 277077 to dataframe
# appended count 277144 to dataframe
# appended count 277145 to dataframe
# appended count 277146 to dataframe
# appended count 277147 to dataframe
# appended count 277149 to dataframe
# appended count 277450 to dataframe
# appended count 277451 to dataframe
# appended count 279728 to dataframe
# appended count 279729 to dataframe
# appended count 281187 to dataframe
# appended count 281963 to dataframe
# appended count 285987 to dataframe
# appended count 286362 to dataframe
# appended count 290768 to dataframe
# appended count 291714 to dataframe
# appended count 291813 to dataframe
# appended count 291819 to dataframe
# appended count 293902 to dataframe
# appended count 293908 to dataframe
# appended count 294022 to dataframe
# appended count 294025 to dataframe
# appended count 294028 to dataframe
# appended count 294030 to dataframe
# appended count 294032 to dataframe
# appended count 294033 to dataframe
# appended count 294034 to dataframe
# appended count 294036 to dataframe
# appended count 294038 to dataframe
# appended count 294040 to dataframe
# appended count 294056 to dataframe
# appended count 294058 to dataframe
# appended count 294060 to dataframe
# appended count 294153 to dataframe
# appended count 295166 to dataframe
# appended count 295173 to dataframe
# appended count 295546 to dataframe
# appended count 295611 to dataframe
# appended count 297393 to dataframe
# appended count 297394 to dataframe
# appended count 297395 to dataframe
# appended count 297397 to dataframe
# appended count 298603 to dataframe
# appended count 298606 to dataframe
# appended count 298610 to dataframe
# appended count 298619 to dataframe
# appended count 299451 to dataframe
# appended count 299455 to dataframe
# appended count 300091 to dataframe
# appended count 300148 to dataframe
# appended count 300154 to dataframe
# appended count 300155 to dataframe
# appended count 300156 to dataframe
# appended count 300158 to dataframe
# appended count 300160 to dataframe
# appended count 300161 to dataframe
# appended count 300162 to dataframe
# appended count 300163 to dataframe
# appended count 300173 to dataframe
# appended count 300174 to dataframe
# appended count 300949 to dataframe
# appended count 300952 to dataframe
# appended count 300954 to dataframe
# appended count 301182 to dataframe
# appended count 301188 to dataframe
# appended count 301189 to dataframe
# appended count 301194 to dataframe
# appended count 301196 to dataframe
# appended count 301203 to dataframe
# appended count 301204 to dataframe
# appended count 301224 to dataframe
# appended count 301229 to dataframe
# appended count 301765 to dataframe
# appended count 302791 to dataframe
# appended count 302806 to dataframe
# appended count 302808 to dataframe
# appended count 302819 to dataframe
# appended count 302842 to dataframe
# appended count 303059 to dataframe
# appended count 303746 to dataframe
# appended count 303754 to dataframe
# appended count 303773 to dataframe
# appended count 305746 to dataframe
# appended count 305747 to dataframe
# appended count 305934 to dataframe
# appended count 306084 to dataframe
# appended count 306085 to dataframe
# appended count 306086 to dataframe
# appended count 306087 to dataframe
# appended count 306089 to dataframe
# appended count 306090 to dataframe
# appended count 306091 to dataframe
# appended count 306092 to dataframe
# appended count 306093 to dataframe
# appended count 306094 to dataframe
# appended count 306100 to dataframe
# appended count 306111 to dataframe
# appended count 306116 to dataframe
# appended count 306125 to dataframe
# appended count 306240 to dataframe
# appended count 308000 to dataframe
# appended count 308002 to dataframe
# appended count 308003 to dataframe
# appended count 308022 to dataframe
# appended count 308029 to dataframe
# appended count 308031 to dataframe
# appended count 308042 to dataframe
# appended count 308045 to dataframe
# appended count 308053 to dataframe
# appended count 308153 to dataframe
# appended count 310540 to dataframe
# appended count 313219 to dataframe
# appended count 313258 to dataframe
# appended count 313301 to dataframe
# appended count 313498 to dataframe
# appended count 313870 to dataframe
# appended count 313911 to dataframe
# appended count 313920 to dataframe
# appended count 313939 to dataframe
# appended count 315062 to dataframe
# appended count 315074 to dataframe
# appended count 315415 to dataframe
# appended count 315418 to dataframe
# appended count 315420 to dataframe
# appended count 315421 to dataframe
# appended count 315654 to dataframe
# appended count 315655 to dataframe
# appended count 315902 to dataframe
# appended count 316114 to dataframe
# appended count 317771 to dataframe
# appended count 317772 to dataframe
# appended count 317773 to dataframe
# appended count 317860 to dataframe
# appended count 318151 to dataframe
# appended count 318163 to dataframe
# appended count 318166 to dataframe
# appended count 318410 to dataframe
# appended count 318411 to dataframe
# appended count 318840 to dataframe
# appended count 318841 to dataframe
# appended count 318882 to dataframe
# appended count 318908 to dataframe
# appended count 319285 to dataframe
# appended count 319287 to dataframe
# appended count 319288 to dataframe
# appended count 319290 to dataframe
# appended count 319291 to dataframe
# appended count 319292 to dataframe
# appended count 319293 to dataframe
# appended count 319294 to dataframe
# appended count 319296 to dataframe
# appended count 319297 to dataframe
# appended count 319298 to dataframe
# appended count 319299 to dataframe
# appended count 319300 to dataframe
# appended count 319301 to dataframe
# appended count 319540 to dataframe
# appended count 320323 to dataframe
# appended count 320357 to dataframe
# appended count 320369 to dataframe
# appended count 320464 to dataframe
# appended count 320500 to dataframe
# appended count 324705 to dataframe
# appended count 326031 to dataframe
# appended count 326032 to dataframe
# appended count 326155 to dataframe
# appended count 327422 to dataframe
# appended count 327620 to dataframe
# appended count 327623 to dataframe
# appended count 327625 to dataframe
# appended count 327632 to dataframe
# appended count 327635 to dataframe
# appended count 327638 to dataframe
# appended count 330348 to dataframe
# appended count 330349 to dataframe
# appended count 330351 to dataframe
# appended count 330352 to dataframe
# appended count 331050 to dataframe
# appended count 331051 to dataframe
# appended count 331052 to dataframe
# appended count 331054 to dataframe
# appended count 331055 to dataframe
# appended count 331056 to dataframe
# appended count 331057 to dataframe
# appended count 332229 to dataframe
# appended count 333168 to dataframe
# appended count 335855 to dataframe
# appended count 336129 to dataframe
# appended count 336130 to dataframe
# appended count 336134 to dataframe
# appended count 336138 to dataframe
# appended count 336141 to dataframe
# appended count 336142 to dataframe
# appended count 336144 to dataframe
# appended count 336881 to dataframe
# appended count 337813 to dataframe
# appended count 337895 to dataframe
# appended count 337897 to dataframe
# appended count 337900 to dataframe
# appended count 341590 to dataframe
# appended count 342258 to dataframe
# appended count 342509 to dataframe
# appended count 342673 to dataframe
# appended count 342674 to dataframe
# appended count 343541 to dataframe
# appended count 343557 to dataframe
# appended count 343594 to dataframe
# appended count 343615 to dataframe
# appended count 343628 to dataframe
# appended count 344085 to dataframe
# appended count 344383 to dataframe
# appended count 344402 to dataframe
# appended count 345111 to dataframe
# appended count 345353 to dataframe
# appended count 345360 to dataframe
# appended count 345366 to dataframe
# appended count 345375 to dataframe
# appended count 345472 to dataframe
# appended count 347185 to dataframe
# appended count 347191 to dataframe
# appended count 348692 to dataframe
# appended count 348696 to dataframe
# appended count 348836 to dataframe
# appended count 348844 to dataframe
# appended count 348991 to dataframe
# appended count 349705 to dataframe
# appended count 351615 to dataframe
# appended count 352460 to dataframe
# appended count 352667 to dataframe
# appended count 353547 to dataframe
# appended count 355421 to dataframe
# appended count 356777 to dataframe
# appended count 358242 to dataframe
# appended count 358751 to dataframe
# appended count 363196 to dataframe
# appended count 363222 to dataframe
# appended count 363276 to dataframe
# appended count 363415 to dataframe
# appended count 363429 to dataframe
# appended count 363441 to dataframe
# appended count 364757 to dataframe
# appended count 366910 to dataframe
# appended count 369060 to dataframe
# appended count 369062 to dataframe
# appended count 369063 to dataframe
# appended count 369064 to dataframe
# appended count 369072 to dataframe
# appended count 369074 to dataframe
# appended count 369077 to dataframe
# appended count 371821 to dataframe
# appended count 372163 to dataframe
# appended count 372176 to dataframe
# appended count 372466 to dataframe
# appended count 372467 to dataframe
# appended count 372468 to dataframe
# appended count 373866 to dataframe
# appended count 375991 to dataframe
# appended count 375992 to dataframe
# appended count 376155 to dataframe
# appended count 376158 to dataframe
# appended count 376159 to dataframe
# appended count 376161 to dataframe
# appended count 376162 to dataframe
# appended count 376164 to dataframe
# appended count 376166 to dataframe
# appended count 378227 to dataframe
# appended count 378241 to dataframe
# appended count 378242 to dataframe
# appended count 378243 to dataframe
# appended count 378244 to dataframe
# appended count 378381 to dataframe
# appended count 378382 to dataframe
# appended count 378383 to dataframe
# appended count 378385 to dataframe
# appended count 378741 to dataframe
# appended count 378742 to dataframe
# appended count 381204 to dataframe
# appended count 381223 to dataframe
# appended count 381403 to dataframe
# appended count 381409 to dataframe
# appended count 381564 to dataframe
# appended count 382077 to dataframe
# appended count 383148 to dataframe
# appended count 383299 to dataframe
# appended count 385547 to dataframe
# appended count 385697 to dataframe
# appended count 386832 to dataframe
# appended count 386833 to dataframe
# appended count 386834 to dataframe
# appended count 388646 to dataframe
# appended count 389069 to dataframe
# appended count 389116 to dataframe
# appended count 389208 to dataframe
# appended count 389227 to dataframe
# appended count 389236 to dataframe
# appended count 392046 to dataframe
# appended count 392055 to dataframe
# appended count 392063 to dataframe
# appended count 392064 to dataframe
# appended count 392066 to dataframe
# appended count 392071 to dataframe
# appended count 392266 to dataframe
# appended count 392374 to dataframe
# appended count 393792 to dataframe
# appended count 393852 to dataframe
# appended count 393856 to dataframe
# appended count 393857 to dataframe
# appended count 393858 to dataframe
# appended count 393870 to dataframe
# appended count 393875 to dataframe
# appended count 394164 to dataframe
# appended count 394165 to dataframe
# appended count 395129 to dataframe
# appended count 395131 to dataframe
# appended count 395132 to dataframe
# appended count 396105 to dataframe
# appended count 397990 to dataframe
# appended count 398000 to dataframe
# appended count 398001 to dataframe
# appended count 398004 to dataframe
# appended count 398864 to dataframe
# appended count 398869 to dataframe
# appended count 398880 to dataframe
# appended count 398883 to dataframe
# appended count 400658 to dataframe
# appended count 401959 to dataframe
# appended count 402021 to dataframe
# appended count 402030 to dataframe
# appended count 402035 to dataframe
# appended count 402039 to dataframe
# appended count 402941 to dataframe
# appended count 402955 to dataframe
# appended count 403252 to dataframe
# appended count 403355 to dataframe
# appended count 404613 to dataframe
# appended count 405549 to dataframe
# appended count 407955 to dataframe
# appended count 407956 to dataframe
# appended count 407957 to dataframe
# appended count 407960 to dataframe
# appended count 408805 to dataframe
# appended count 409775 to dataframe
# appended count 412562 to dataframe
# appended count 415235 to dataframe
# appended count 418509 to dataframe
# appended count 420248 to dataframe
# appended count 420422 to dataframe
# appended count 420424 to dataframe
# appended count 420449 to dataframe
# appended count 421370 to dataframe
# appended count 421847 to dataframe
# appended count 421863 to dataframe
# appended count 421867 to dataframe
# appended count 421874 to dataframe
# appended count 421884 to dataframe
# appended count 421896 to dataframe
# appended count 421925 to dataframe
# appended count 421927 to dataframe
# appended count 421970 to dataframe
# appended count 422072 to dataframe
# appended count 422096 to dataframe
# appended count 422149 to dataframe
# appended count 422158 to dataframe
# appended count 422205 to dataframe
# appended count 422209 to dataframe
# appended count 426558 to dataframe
# appended count 426786 to dataframe
# appended count 427193 to dataframe
# appended count 427258 to dataframe
# appended count 427259 to dataframe
# appended count 427294 to dataframe
# appended count 427295 to dataframe
# appended count 427302 to dataframe
# appended count 427305 to dataframe
# appended count 427307 to dataframe
# appended count 427320 to dataframe
# appended count 428268 to dataframe
# appended count 431048 to dataframe
# appended count 432774 to dataframe
# appended count 432782 to dataframe
# appended count 432787 to dataframe
# appended count 432842 to dataframe
# appended count 432844 to dataframe
# appended count 432852 to dataframe
# appended count 432862 to dataframe
# appended count 432863 to dataframe
# appended count 432883 to dataframe
# appended count 432884 to dataframe
# appended count 432885 to dataframe
# appended count 432918 to dataframe
# appended count 435039 to dataframe
# appended count 435371 to dataframe
# appended count 436125 to dataframe
# appended count 437421 to dataframe
# appended count 437422 to dataframe
# appended count 437425 to dataframe
# appended count 437432 to dataframe
# appended count 437433 to dataframe
# ...
# appended count 1242463 to dataframe
# appended count 1242511 to dataframe
# appended count 1242534 to dataframe
# appended count 1242535 to dataframe
# appended count 1243964 to dataframe
# appended count 1250128 to dataframe
# appended count 1251834 to dataframe
# appended count 1251835 to dataframe
# appended count 1251839 to dataframe
# appended count 1251840 to dataframe
# appended count 1255867 to dataframe
# appended count 1259791 to dataframe
# appended count 1259918 to dataframe
# appended count 1262153 to dataframe
# appended count 1262158 to dataframe
# appended count 1262159 to dataframe
# appended count 1266202 to dataframe
# appended count 1266204 to dataframe
# appended count 1266461 to dataframe
# appended count 1266470 to dataframe
# appended count 1266475 to dataframe
# appended count 1266479 to dataframe
# appended count 1266931 to dataframe
# appended count 1268286 to dataframe
# appended count 1268289 to dataframe
# appended count 1269919 to dataframe
# appended count 1269923 to dataframe
# appended count 1269924 to dataframe
# appended count 1269925 to dataframe
# appended count 1269926 to dataframe
# appended count 1269928 to dataframe
# appended count 1269929 to dataframe
# appended count 1271342 to dataframe
# appended count 1272152 to dataframe
# appended count 1280286 to dataframe
# appended count 1281879 to dataframe
# appended count 1283948 to dataframe
# appended count 1289629 to dataframe
# appended count 1293682 to dataframe
# appended count 1293684 to dataframe
# appended count 1293685 to dataframe
# appended count 1293686 to dataframe
# appended count 1293687 to dataframe
# appended count 1294049 to dataframe
# appended count 1294050 to dataframe
# appended count 1294087 to dataframe
# appended count 1295452 to dataframe
# appended count 1296111 to dataframe
# appended count 1297507 to dataframe
# appended count 1297509 to dataframe
# appended count 1301427 to dataframe
# appended count 1305094 to dataframe
# appended count 1306328 to dataframe
# appended count 1317717 to dataframe
# appended count 1317718 to dataframe
# appended count 1317719 to dataframe
# appended count 1317721 to dataframe
# appended count 1321498 to dataframe
# appended count 1321530 to dataframe
# appended count 1321585 to dataframe
# appended count 1321598 to dataframe
# appended count 1321606 to dataframe
# appended count 1321613 to dataframe
# appended count 1324280 to dataframe
# appended count 1326265 to dataframe
# appended count 1331742 to dataframe
# appended count 1332737 to dataframe
# appended count 1337664 to dataframe
# appended count 1341319 to dataframe
# appended count 1341320 to dataframe
# appended count 1341322 to dataframe
# appended count 1341325 to dataframe
# appended count 1341328 to dataframe
# appended count 1341329 to dataframe
# appended count 1341333 to dataframe
# appended count 1341335 to dataframe
# appended count 1341338 to dataframe
# appended count 1341346 to dataframe
# appended count 1345814 to dataframe
# appended count 1345815 to dataframe
# appended count 1347636 to dataframe
# appended count 1347646 to dataframe
# appended count 1347666 to dataframe
# appended count 1347669 to dataframe
# appended count 1347670 to dataframe
# appended count 1347681 to dataframe
# appended count 1349395 to dataframe
# appended count 1351061 to dataframe
# appended count 1355284 to dataframe
# appended count 1355428 to dataframe
# appended count 1355439 to dataframe
# appended count 1356202 to dataframe
# appended count 1356213 to dataframe
# appended count 1357706 to dataframe
# appended count 1358843 to dataframe
# appended count 1364750 to dataframe
# appended count 1366013 to dataframe
# appended count 1366014 to dataframe
# appended count 1366018 to dataframe
# appended count 1366026 to dataframe
# appended count 1369373 to dataframe
# appended count 1369378 to dataframe
# appended count 1376635 to dataframe
# appended count 1376637 to dataframe
# appended count 1376652 to dataframe
# appended count 1376662 to dataframe
# appended count 1377251 to dataframe
# appended count 1377287 to dataframe
# appended count 1380224 to dataframe
# appended count 1380225 to dataframe
# appended count 1381636 to dataframe
# appended count 1381637 to dataframe
# appended count 1381643 to dataframe
# appended count 1381645 to dataframe
# appended count 1381647 to dataframe
# appended count 1382031 to dataframe
# appended count 1382036 to dataframe
# appended count 1383163 to dataframe
# appended count 1391516 to dataframe
# appended count 1391517 to dataframe
# appended count 1391520 to dataframe
# appended count 1393285 to dataframe
# appended count 1394020 to dataframe
# appended count 1394667 to dataframe
# appended count 1400543 to dataframe
# appended count 1400552 to dataframe
# appended count 1400566 to dataframe
# appended count 1403162 to dataframe
# appended count 1403170 to dataframe
# appended count 1403174 to dataframe
# appended count 1403176 to dataframe
# appended count 1403177 to dataframe
# appended count 1403179 to dataframe
# appended count 1404270 to dataframe
# appended count 1404271 to dataframe
# appended count 1411532 to dataframe
# appended count 1411733 to dataframe
# appended count 1411745 to dataframe
# appended count 1413391 to dataframe
# appended count 1413393 to dataframe
# appended count 1413396 to dataframe
# appended count 1413411 to dataframe
# appended count 1417942 to dataframe
# appended count 1418001 to dataframe
# appended count 1420644 to dataframe
# appended count 1434896 to dataframe
# appended count 1452210 to dataframe
# appended count 1452211 to dataframe
# appended count 1466051 to dataframe
# appended count 1468158 to dataframe
# appended count 1468174 to dataframe
# appended count 1468278 to dataframe
# appended count 1468279 to dataframe
# appended count 1468283 to dataframe
# appended count 1468753 to dataframe
# appended count 1470375 to dataframe
# appended count 1470377 to dataframe
# appended count 1470381 to dataframe
# appended count 1470383 to dataframe
# appended count 1470387 to dataframe
# appended count 1470390 to dataframe
# appended count 1470392 to dataframe
# appended count 1470394 to dataframe
# appended count 1474558 to dataframe
# appended count 1474563 to dataframe
# appended count 1476803 to dataframe
# appended count 1477455 to dataframe
# appended count 1477457 to dataframe
# appended count 1477460 to dataframe
# appended count 1477466 to dataframe
# appended count 1478930 to dataframe
# appended count 1484947 to dataframe
# appended count 1484956 to dataframe
# appended count 1487775 to dataframe
# appended count 1487784 to dataframe
# appended count 1487785 to dataframe
# appended count 1487786 to dataframe
# appended count 1487787 to dataframe
# appended count 1487798 to dataframe
# appended count 1487800 to dataframe
# appended count 1491172 to dataframe
# appended count 1492543 to dataframe
# appended count 1492545 to dataframe
# appended count 1492787 to dataframe
# appended count 1493848 to dataframe
# appended count 1493849 to dataframe
# appended count 1497789 to dataframe
# appended count 1497792 to dataframe
# appended count 1505054 to dataframe
# appended count 1505055 to dataframe
# appended count 1505162 to dataframe
# appended count 1505164 to dataframe
# appended count 1506241 to dataframe
# appended count 1511463 to dataframe
# appended count 1517505 to dataframe
# appended count 1518193 to dataframe
# appended count 1520456 to dataframe
# appended count 1520457 to dataframe
# appended count 1520458 to dataframe
# appended count 1520459 to dataframe
# appended count 1520703 to dataframe
# appended count 1524497 to dataframe
# appended count 1526903 to dataframe
# appended count 1532881 to dataframe
# appended count 1534310 to dataframe
# appended count 1534582 to dataframe
# appended count 1535817 to dataframe
# appended count 1535820 to dataframe
# appended count 1544245 to dataframe
# appended count 1546293 to dataframe
# appended count 1548657 to dataframe
# appended count 1550245 to dataframe
# appended count 1550247 to dataframe
# appended count 1559420 to dataframe
# appended count 1559429 to dataframe
# appended count 1559433 to dataframe
# appended count 1559852 to dataframe
# appended count 1567986 to dataframe
# appended count 1568000 to dataframe
# appended count 1571883 to dataframe
# appended count 1571888 to dataframe
# appended count 1577305 to dataframe
# appended count 1578870 to dataframe
# appended count 1578874 to dataframe
# appended count 1578878 to dataframe
# appended count 1578967 to dataframe
# appended count 1587579 to dataframe
# appended count 1592910 to dataframe
# appended count 1594398 to dataframe
# appended count 1598629 to dataframe
# appended count 1602711 to dataframe
# appended count 1602718 to dataframe
# appended count 1602719 to dataframe
# appended count 1602738 to dataframe
# appended count 1603505 to dataframe
# appended count 1603813 to dataframe
# appended count 1605720 to dataframe
# appended count 1610211 to dataframe
# appended count 1610212 to dataframe
# appended count 1610213 to dataframe
# appended count 1610214 to dataframe
# appended count 1610215 to dataframe
# appended count 1610216 to dataframe
# appended count 1610217 to dataframe
# appended count 1610219 to dataframe
# appended count 1610222 to dataframe
# appended count 1613001 to dataframe
# appended count 1613004 to dataframe
# appended count 1613006 to dataframe
# appended count 1613008 to dataframe
# appended count 1613009 to dataframe
# appended count 1613011 to dataframe
# appended count 1613017 to dataframe
# appended count 1613018 to dataframe
# appended count 1613021 to dataframe
# appended count 1613023 to dataframe
# appended count 1613024 to dataframe
# appended count 1613025 to dataframe
# appended count 1613029 to dataframe
# appended count 1613032 to dataframe
# appended count 1613036 to dataframe
# appended count 1613038 to dataframe
# appended count 1613039 to dataframe
# appended count 1613041 to dataframe
# appended count 1613042 to dataframe
# appended count 1613044 to dataframe
# appended count 1613045 to dataframe
# appended count 1613046 to dataframe
# appended count 1613047 to dataframe
# appended count 1613048 to dataframe
# appended count 1613049 to dataframe
# appended count 1613050 to dataframe
# appended count 1613051 to dataframe
# appended count 1613052 to dataframe
# appended count 1613055 to dataframe
# appended count 1613056 to dataframe
# appended count 1613057 to dataframe
# appended count 1613058 to dataframe
# appended count 1613059 to dataframe
# appended count 1613061 to dataframe
# appended count 1613062 to dataframe
# appended count 1613063 to dataframe
# appended count 1613064 to dataframe
# appended count 1613066 to dataframe
# appended count 1613067 to dataframe
# appended count 1613068 to dataframe
# appended count 1613070 to dataframe
# appended count 1613071 to dataframe
# appended count 1613073 to dataframe
# appended count 1613075 to dataframe
# appended count 1613079 to dataframe
# appended count 1613081 to dataframe
# appended count 1614198 to dataframe
# appended count 1614199 to dataframe
# appended count 1614200 to dataframe
# appended count 1614676 to dataframe
# appended count 1614678 to dataframe
# appended count 1629113 to dataframe
# appended count 1630960 to dataframe
# appended count 1632727 to dataframe
# appended count 1636092 to dataframe
# appended count 1636093 to dataframe
# appended count 1636103 to dataframe
# appended count 1637554 to dataframe
# appended count 1637628 to dataframe
# appended count 1637631 to dataframe
# appended count 1643833 to dataframe
# appended count 1658034 to dataframe
# appended count 1661522 to dataframe
# appended count 1662785 to dataframe
# appended count 1668644 to dataframe
# appended count 1670794 to dataframe
# appended count 1680141 to dataframe
# appended count 1682337 to dataframe
# appended count 1682338 to dataframe
# appended count 1682339 to dataframe
# appended count 1682340 to dataframe
# appended count 1682464 to dataframe
# appended count 1688104 to dataframe
# appended count 1692375 to dataframe
# appended count 1709672 to dataframe
# appended count 1710635 to dataframe
# appended count 1710639 to dataframe
# appended count 1710643 to dataframe
# appended count 1710656 to dataframe
# appended count 1710663 to dataframe
# appended count 1710721 to dataframe
# appended count 1713318 to dataframe
# appended count 1713995 to dataframe
# appended count 1715297 to dataframe
# appended count 1715384 to dataframe
# appended count 1716878 to dataframe
# appended count 1717011 to dataframe
# appended count 1734092 to dataframe
# appended count 1735919 to dataframe
# appended count 1735920 to dataframe
# appended count 1735923 to dataframe
# appended count 1735924 to dataframe
# appended count 1735926 to dataframe
# appended count 1735927 to dataframe
# appended count 1735928 to dataframe
# appended count 1735939 to dataframe
# appended count 1735972 to dataframe
# appended count 1735978 to dataframe
# appended count 1735997 to dataframe
# appended count 1743021 to dataframe
# appended count 1743029 to dataframe
# appended count 1743030 to dataframe
# appended count 1743044 to dataframe
# appended count 1743047 to dataframe
# appended count 1743049 to dataframe
# appended count 1750064 to dataframe
# appended count 1765482 to dataframe
# appended count 1766099 to dataframe
# appended count 1768760 to dataframe
# appended count 1778022 to dataframe
# appended count 1778027 to dataframe
# appended count 1778060 to dataframe
# appended count 1778097 to dataframe
# appended count 1778101 to dataframe
# appended count 1778102 to dataframe
# appended count 1778103 to dataframe
# appended count 1778104 to dataframe
# appended count 1778107 to dataframe
# appended count 1783783 to dataframe
# appended count 1783789 to dataframe
# appended count 1796232 to dataframe
# appended count 1799734 to dataframe
# appended count 1799742 to dataframe
# appended count 1799744 to dataframe
# appended count 1799746 to dataframe
# appended count 1799747 to dataframe
# appended count 1799749 to dataframe
# appended count 1809072 to dataframe
# appended count 1816242 to dataframe
# appended count 1816253 to dataframe
# appended count 1817529 to dataframe
# appended count 1817889 to dataframe
# appended count 1822726 to dataframe
# appended count 1826274 to dataframe
# appended count 1827199 to dataframe
# appended count 1827212 to dataframe
# appended count 1827220 to dataframe
# appended count 1827242 to dataframe
# appended count 1827250 to dataframe
# appended count 1830656 to dataframe
# appended count 1830678 to dataframe
# appended count 1836087 to dataframe
# appended count 1858568 to dataframe
# appended count 1869691 to dataframe
# appended count 1874608 to dataframe
# appended count 1889850 to dataframe
# appended count 1889851 to dataframe
# appended count 1898736 to dataframe
# appended count 1898740 to dataframe
# appended count 1913544 to dataframe
# appended count 1916317 to dataframe
# appended count 1916942 to dataframe
# appended count 1916950 to dataframe
# appended count 1939434 to dataframe
# appended count 1939436 to dataframe
# appended count 1947504 to dataframe
# appended count 1947508 to dataframe
# appended count 1947526 to dataframe
# appended count 1962639 to dataframe
# appended count 1962640 to dataframe
# appended count 1962659 to dataframe
# appended count 1962663 to dataframe
# appended count 1962664 to dataframe
# appended count 1962665 to dataframe
# appended count 1967905 to dataframe
# appended count 1976065 to dataframe
# appended count 1988013 to dataframe
# appended count 1996257 to dataframe
# appended count 1996260 to dataframe
# appended count 1996261 to dataframe
# appended count 2031687 to dataframe
# appended count 2042816 to dataframe
# appended count 2066607 to dataframe
# appended count 2073363 to dataframe
# appended count 2093231 to dataframe
# appended count 2093234 to dataframe
# appended count 2098331 to dataframe
# appended count 2098332 to dataframe
# appended count 2098336 to dataframe
# appended count 2101462 to dataframe
# appended count 2104195 to dataframe
# appended count 2125814 to dataframe
# appended count 2125816 to dataframe
# appended count 2128460 to dataframe
# appended count 2140950 to dataframe
# appended count 2155526 to dataframe
# appended count 2161055 to dataframe
# appended count 2192545 to dataframe
# appended count 2192548 to dataframe
# appended count 2195731 to dataframe
# appended count 2203374 to dataframe
# appended count 2203377 to dataframe
# appended count 2210962 to dataframe
# appended count 2225388 to dataframe
# appended count 2228513 to dataframe
# appended count 2228541 to dataframe
# appended count 2228550 to dataframe
# appended count 2228608 to dataframe

# %%
#save css_df as csv file
#css_df.to_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\css_df.csv')

# %%
len(css_df.year)
# Out:
# 3223

# %%
import pandas as pd
from collections import defaultdict

author_data = pd.read_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\author_df.csv',dtype=str)
css_df = pd.read_csv(r'C:\Users\khali\OneDrive - Danmarks Tekniske Universitet\6. semester\Computational Social Science\Computational-Social-Science-Exercises\css_df.csv',dtype=str)
css_df.drop(columns=['Unnamed: 0.1'],inplace=True)
css_df['year'] = css_df['year'].astype(float).astype(int)
css_df['citationCount'] = css_df['citationCount'].astype(float).astype(int)

# %%
author_data['authorId'][1
]
# Out:
# '3276812'

# %%
css_df.sort_values(by=['citationCount'],ascending=False)['title'].iloc[0:10]
# Out:
# 1284    Conducting behavioral research on Amazon’s Mec...
# 1253    A 61-million-person experiment in social influ...
# 2794    Exposure to ideologically diverse news and opi...
# 2803    Automated Hate Speech Detection and the Proble...
# 291     Estimation and Inference of Heterogeneous Trea...
# 28      Commentary on Ferguson, et al., “Impact of Non...
# 2497    How Censorship in China Allows Government Crit...
# 2687    Inherent Trade-Offs in the Fair Determination ...
# 49      Multiscale mobility networks and the spatial s...
# 1235    Filter Bubbles, Echo Chambers, and Online News...
# Name: title, dtype: object

# %%
#make dictionary for collab network
import ast
collab_network = {}

for i in range(len(css_df)):
    paper_authorId = ast.literal_eval(css_df.iloc[i]['authorIds'])

    for auth1 in paper_authorId:
        for auth2 in paper_authorId:
            if auth1 != auth2:
                if (auth1,auth2) in collab_network:
                    collab_network[(auth1,auth2)] += 1
                else:
                    collab_network[(auth1,auth2)] = 1

edgelist = [(x[0][0], x[0][1], x[1]) for x in collab_network.items()]

# %%
print(len(edgelist))
edgelist
# Out:
# 18248
# [('71958542', '50657181', 1),
#  ('71958542', '1573630453', 1),
#  ('71958542', '1573630578', 1),
#  ('71958542', '48988567', 1),
#  ('71958542', '2053577568', 1),
#  ('50657181', '71958542', 1),
#  ('50657181', '1573630453', 1),
#  ('50657181', '1573630578', 1),
#  ('50657181', '48988567', 1),
#  ('50657181', '2053577568', 1),
#  ('1573630453', '71958542', 1),
#  ('1573630453', '50657181', 1),
#  ('1573630453', '1573630578', 1),
#  ('1573630453', '48988567', 1),
#  ('1573630453', '2053577568', 1),
#  ('1573630578', '71958542', 1),
#  ('1573630578', '50657181', 1),
#  ('1573630578', '1573630453', 1),
#  ('1573630578', '48988567', 1),
#  ('1573630578', '2053577568', 1),
#  ('48988567', '71958542', 1),
#  ('48988567', '50657181', 1),
#  ('48988567', '1573630453', 1),
#  ('48988567', '1573630578', 1),
#  ('48988567', '2053577568', 1),
#  ('2053577568', '71958542', 1),
#  ('2053577568', '50657181', 1),
#  ('2053577568', '1573630453', 1),
#  ('2053577568', '1573630578', 1),
#  ('2053577568', '48988567', 1),
#  ('145883179', '2703478', 2),
#  ('145883179', '1405628931', 2),
#  ('145883179', '1684687', 2),
#  ('2703478', '145883179', 2),
#  ('2703478', '1405628931', 2),
#  ('2703478', '1684687', 4),
#  ('1405628931', '145883179', 2),
#  ('1405628931', '2703478', 2),
#  ('1405628931', '1684687', 2),
#  ('1684687', '145883179', 2),
#  ('1684687', '2703478', 4),
#  ('1684687', '1405628931', 2),
#  ('145883179', '32261909', 1),
#  ('145883179', '1821014', 1),
#  ('32261909', '145883179', 1),
#  ('32261909', '1821014', 6),
#  ('1821014', '145883179', 1),
#  ('1821014', '32261909', 6),
#  ('145752168', '4902230', 1),
#  ('145752168', '46590719', 1),
#  ('145752168', '3482524', 1),
#  ('145752168', '31485385', 1),
#  ('145752168', '148176055', 6),
#  ('4902230', '145752168', 1),
#  ('4902230', '46590719', 1),
#  ('3357178', '1700149', 1),
#  ('1490970698', '1838478', 1),
#  ('1490970698', '144002439', 1),
#  ('1490970698', '3357178', 1),
#  ('1490970698', '1700149', 1),
#  ('1700149', '1838478', 1),
#  ('1700149', '144002439', 1),
#  ('1700149', '3357178', 1),
#  ('1700149', '1490970698', 1),
#  ('31722922', '38818867', 1),
#  ('31722922', '144263467', 1),
#  ('31722922', '25512473', 1),
#  ('31722922', '40016674', 1),
#  ('31722922', '1976593', 1),
#  ('31722922', '2478983', 1),
#  ('31722922', '2404363', 1),
#  ('31722922', '1728390', 1),
#  ('38818867', '31722922', 1),
#  ('38818867', '144263467', 1),
#  ('38818867', '25512473', 1),
#  ('38818867', '40016674', 1),
#  ('38818867', '1976593', 1),
#  ('38818867', '2478983', 1),
#  ('38818867', '2404363', 1),
#  ('38818867', '1728390', 1),
#  ('144263467', '31722922', 1),
#  ('144263467', '38818867', 1),
#  ('144263467', '25512473', 1),
#  ('144263467', '40016674', 1),
#  ('144263467', '1976593', 1),
#  ('144263467', '2478983', 1),
#  ('144263467', '2404363', 1),
#  ('144263467', '1728390', 1),
#  ('25512473', '31722922', 1),
#  ('25512473', '38818867', 1),
#  ('25512473', '144263467', 1),
#  ('25512473', '40016674', 1),
#  ('25512473', '1976593', 1),
#  ('25512473', '2478983', 1),
#  ('25512473', '2404363', 1),
#  ('25512473', '1728390', 1),
#  ('40016674', '31722922', 1),
#  ('40016674', '38818867', 1),
#  ('40016674', '144263467', 1),
#  ('40016674', '25512473', 1),
#  ('40016674', '1976593', 1),
#  ('40016674', '2478983', 1),
#  ('40016674', '2404363', 1),
#  ('40016674', '1728390', 1),
#  ('1976593', '31722922', 1),
#  ('1976593', '38818867', 1),
#  ('1976593', '144263467', 1),
#  ('1976593', '25512473', 1),
#  ('1976593', '40016674', 1),
#  ('1976593', '2478983', 1),
#  ('1976593', '2404363', 1),
#  ('1976593', '1728390', 1),
#  ('2478983', '31722922', 1),
#  ('2478983', '38818867', 1),
#  ('2478983', '144263467', 1),
#  ('2478983', '25512473', 1),
#  ('2478983', '40016674', 1),
#  ('2478983', '1976593', 1),
#  ('2478983', '2404363', 1),
#  ('2478983', '1728390', 1),
#  ('2404363', '31722922', 1),
#  ('2404363', '38818867', 1),
#  ('2404363', '144263467', 1),
#  ('2404363', '25512473', 1),
#  ('2404363', '40016674', 1),
#  ('2404363', '1976593', 1),
#  ('2404363', '2478983', 1),
#  ('2404363', '1728390', 1),
#  ('1728390', '31722922', 1),
#  ('1728390', '38818867', 1),
#  ('1728390', '144263467', 1),
#  ('1728390', '25512473', 1),
#  ('1728390', '40016674', 1),
#  ('1728390', '1976593', 1),
#  ('1728390', '2478983', 1),
#  ('1728390', '2404363', 1),
#  ('1707467', '39157073', 1),
#  ('39157073', '1707467', 1),
#  ('33295892', '1379969603', 1),
#  ('33295892', '83427662', 1),
#  ('33295892', '2709512', 1),
#  ('33295892', '49248752', 1),
#  ('33295892', '70224648', 1),
#  ('33295892', '10721627', 1),
#  ('33295892', '51913730', 1),
#  ('3280421', '71343039', 1),
#  ('3280421', '2627759', 3),
#  ('145748289', '3280421', 3),
#  ('145748289', '71343039', 1),
#  ('145748289', '2627759', 11),
#  ('71343039', '3280421', 1),
#  ('71343039', '145748289', 1),
#  ('71343039', '2627759', 1),
#  ('2627759', '3280421', 3),
#  ('2627759', '145748289', 11),
#  ('2627759', '71343039', 1),
#  ('3280421', '1716665', 2),
#  ('145748289', '1716665', 2),
#  ('2627759', '1716665', 2),
#  ('1716665', '3280421', 2),
#  ('1716665', '145748289', 2),
#  ('1716665', '2627759', 2),
#  ('3280421', '39762878', 2),
#  ('3280421', '143995258', 1),
#  ('3280421', '1695397', 1),
#  ('39762878', '3280421', 2),
#  ('39762878', '143995258', 1),
#  ('39762878', '1695397', 1),
#  ('143995258', '3280421', 1),
#  ('143995258', '39762878', 1),
#  ('143995258', '1695397', 1),
#  ('1695397', '3280421', 1),
#  ('1695397', '39762878', 1),
#  ('1695397', '143995258', 1),
#  ('3280421', '1771117', 1),
#  ('1771117', '3280421', 1),
#  ('1771117', '39762878', 1),
#  ('39762878', '1771117', 1),
#  ('1707561', '116326546', 1),
#  ('1707561', '46633570', 1),
#  ('1707561', '2850437', 1),
#  ('1707561', '6154599', 1),
#  ('1707561', '46231703', 1),
#  ('1707561', '14536938', 1),
#  ('116326546', '1707561', 1),
#  ('116326546', '46633570', 1),
#  ('116326546', '2850437', 1),
#  ('116326546', '6154599', 1),
#  ('116326546', '46231703', 1),
#  ('116326546', '14536938', 1),
#  ('46633570', '1707561', 1),
#  ('46633570', '116326546', 1),
#  ('46633570', '2850437', 1),
#  ('46633570', '6154599', 1),
#  ('46633570', '46231703', 1),
#  ('46633570', '14536938', 1),
#  ('2850437', '1707561', 1),
#  ('2850437', '116326546', 1),
#  ('2850437', '46633570', 1),
#  ('2850437', '6154599', 1),
#  ('2850437', '46231703', 1),
#  ('2850437', '14536938', 1),
#  ('6154599', '1707561', 1),
#  ('6154599', '116326546', 1),
#  ('6154599', '46633570', 1),
#  ('6154599', '2850437', 1),
#  ('6154599', '46231703', 1),
#  ('6154599', '14536938', 1),
#  ('46231703', '1707561', 1),
#  ('46231703', '116326546', 1),
#  ...]

# %%
ast.literal_eval(author_data[author_data['authorId'] == '50657181']['aliases'].values[0])
#author_data[author_data['authorId'] == 50657181]['name'].values[0]
# Out:
# ['Zhang Shuo', 'Zhan Shuo']

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import ast
from collections import defaultdict

G = nx.Graph()
G.add_weighted_edges_from(edgelist)

# %%
#find median citation count of authors in css_df:
css_citation_count = {}
css_first_paper_year = {}
css_author_fullname = {}
css_citation_count_median = {}
css_num_papers = {}
css_author_field = {}

for i in range(len(css_df)):
    paper_authorId = ast.literal_eval(css_df.iloc[i]['authorIds'])
    paper_first_paper_year = css_df.iloc[i]['year']
    for auth in paper_authorId:
        auth = str(auth)
        if auth in css_first_paper_year:
            css_first_paper_year[auth] = min(css_first_paper_year[auth], paper_first_paper_year)
        else:
            css_first_paper_year[auth] = paper_first_paper_year
        if auth in css_citation_count:
            css_citation_count[auth] += [css_df.iloc[i]['citationCount']]
        else:
            css_citation_count[auth] = [css_df.iloc[i]['citationCount']]
#make dictionary with keys as authorId and values as field using css_df pandas dataframe:
for i in range(len(css_df)):
    css_author_field[author_data.iloc[i]['authorId']] = author_data.iloc[i]['field']
css_author_field = {node: css_author_field[node] for node in css_author_field if node in G.nodes()}

#add attributes to nodes:
for node in G.nodes():
    node = str(node)
    author_name = [author_data[author_data['authorId'] == node]['name'].values[0]] if not author_data[author_data['authorId'] == node]['name'].empty else []
    author_aliases = author_data[author_data['authorId'] == node]['aliases'].values.tolist()[0] if not author_data[author_data['authorId'] == node]['aliases'].empty else []
    author_aliases = ast.literal_eval(author_aliases) if (not str(author_aliases) == 'nan' and not author_aliases == []) else str(author_aliases)
    author_aliases = [author_aliases] if isinstance(author_aliases,str) else author_aliases
    author_fullname = author_name + author_aliases
    if author_fullname != []:
        author_fullname = max(author_fullname + author_aliases)
        css_author_fullname[node] = author_fullname
    css_citation_count_median[node] = np.median(np.sort(css_citation_count[node]))
    css_num_papers[node] = len(css_citation_count[node])

# %%
nx.set_node_attributes(G, name = 'name', values = css_author_fullname)
nx.set_node_attributes(G, name = 'citation_count', values = css_citation_count_median)
nx.set_node_attributes(G, name = 'css_papers', values = css_num_papers)
nx.set_node_attributes(G, name = 'top field', values = css_author_field)
nx.set_node_attributes(G, name = 'first_paper_year', values = css_first_paper_year)

# %%
G.nodes()
# Out:
# NodeView(('71958542', '50657181', '1573630453', '1573630578', '48988567', '2053577568', '145883179', '2703478', '1405628931', '1684687', '32261909', '1821014', '145752168', '4902230', '46590719', '3482524', '31485385', '148176055', '2165530', '48569628', '89090110', '143786158', '1752093', '2325084', '1744808', '3076440', '1701341', '3145906', '51435753', '151467651', '49305855', '48245618', '6673771', '2557324', '50663909', '33769943', '30912359', '144386157', '144982806', '1780833', '1685102', '1693341', '1739490', '34996452', '3371403', '145918049', '144441581', '2551214', '46950454', '3271584', '2383424', '101495832', '2107700135', '143900982', '2007521700', '2118744436', '1436038016', '1720151', '48418937', '1746034', '144252495', '1755938', '1779048', '145621251', '1690690', '1851304', '2145946569', '1737486', '3244651', '1826736', '2067699', '2349638', '2038139', '46726748', '1730404', '2836702', '1818812', '80273596', '2202543826', '2685443', '49446819', '41156871', '144728530', '144378428', '2058611087', '51011397', '65794755', '145231161', '144060516', '144326234', '1736360', '2071712759', '144723131', '5536301', '2073417805', '88739154', '146353054', '97925910', '1402342789', '1403230833', '1403854104', '1838478', '2159092', '2499673', '144002439', '3357178', '1490970698', '1700149', '31722922', '38818867', '144263467', '25512473', '40016674', '1976593', '2478983', '2404363', '1728390', '1707467', '39157073', '33295892', '1379969603', '83427662', '2709512', '49248752', '70224648', '10721627', '51913730', '2176093416', '144898884', '1903670', '47206305', '3475001', '6032930', '38972934', '2143194136', '37237998', '133980886', '2024608686', '2057669073', '1391859871', '2128662268', '51428797', '144787428', '2047818403', '3280421', '145748289', '71343039', '2627759', '1716665', '39762878
# 3222          3222     2228608  be177341d20fa035065b04eff9c9c2a8cb9ebabd
#
#                                                   title    year  \
# 0     DESIGN OF A CROSS-BOUNDARY WARNING SYSTEM FOR ...  2019.0
# 1     Monitoring of the Venezuelan exodus through Fa...  2020.0
# 2     Correction: Monitoring of the Venezuelan exodu...  2020.0
# 3     Migrant mobility flows characterized with digi...  2019.0
# 4     Informed consent for linking survey and social...  2021.0
# ...                                                 ...     ...
# 3218  Building Research Infrastructures to Study Dig...  2021.0
# 3219           XiaoMu: an AI-driven assistant for MOOCs  2021.0
# 3220                    Understanding Dropouts in MOOCs  2019.0
# 3221  Infer Implicit Contexts in Real-time Online-to...  2019.0
# 3222  Learning triadic influence in large social net...  2016.0
#
#                                          externalId.DOI  citationCount  \
# 0     {'MAG': '2997661792', 'DOI': '10.35633/inmateh...              2
# 1     {'MAG': '3007572408', 'PubMedCentral': '703495...             30
# 2     {'PubMedCentral': '7064226', 'MAG': '301145846...              4
# 3     {'MAG': '3012900549', 'DBLP': 'journals/corr/a...             19
# 4     {'MAG': '3146101303', 'DOI': '10.29173/IQ988',...              4
# ...                                                 ...            ...
# 3218  {'MAG': '3197955738', 'DOI': '10.1017/S1049096...              5
# 3219  {'DBLP': 'journals/chinaf/Song0LZWFZ21', 'MAG'...              1
# 3220  {'DBLP': 'conf/aaai/Feng0L19', 'MAG': '2905464...            108
# 3221  {'MAG': '3104763847', 'DBLP': 'conf/kdd/Ding0L...              7
# 3222  {'MAG': '2555511564', 'DBLP': 'conf/asunam/Zha...              4
#
#                                               authorIds  \
# 0     ['71958542', '50657181', '1573630453', '157363...
# 1     ['145883179', '2703478', '1405628931', '1684687']
# 2     ['145883179', '2703478', '1405628931', '1684687']
# 3                  ['145883179', '32261909', '1821014']
# 4     ['145752168', '4902230', '46590719', '3482524'...
# ...                                                 ...
# 3218                           ['2488381', '104244453']
# 3219                            ['46199760', '3355580']
# 3220                            ['46199760', '3355580']
# 3221                            ['46199760', '3355580']
# 3222                            ['46199760', '3355580']
#
#                      fields                                       author_field
# 0                       NaN  ['Economics', 'Engineering', 'Computer Science...
# 1     ['Political Science']  ['Economics', 'Computer Science', 'Environment...
# 2             ['Economics']  ['Economics', 'Computer Science', 'Environment...
# 3             ['Economics']     ['Economics', 'Economics', 'Computer Science']
# 4      ['Computer Science']  ['Sociology', 'Computer Science', 'Psychology'...
# ...                     ...                                                ...
# 3218   ['Computer Science']          ['Computer Science', 'Political Science']
# 3219          ['Education']                  ['Computer Science', 'Economics']
# 3220   ['Computer Science']                  ['Computer Science', 'Economics']
# 3221   ['Computer Science']                  ['Computer Science', 'Economics']
# 3222   ['Computer Science']                  ['Computer Science', 'Economics']
#
# [3223 rows x 10 columns]

# %%
author_data[author_data['authorId'] == node]['name']
# Out:
# Series([], Name: name, dtype: object)

# %%
author_data
# Out:
# '104244453'

# %%
# loop through author data and find row where authorId == node:
for i in range(len(author_data)):
    if author_data.iloc[i]['authorId'] == node:
        print(author_data.iloc[i])
